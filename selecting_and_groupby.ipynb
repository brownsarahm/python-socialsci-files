# %%
pwd
# Out:
# 'C:\\Users\\Danie\\Desktop\\python-socialsci-files-nsbe46'

# %%
import pandas as pd

# %%
df_SAFI = pd.read_csv("data/SAFI_clean.csv")

# %%
df_SAFI
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# ..      ...       ...                   ...        ...        ...
# 126     126     Ruaca  2017-05-18T00:00:00Z          3          7
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
# 130     200  Chirodzo  2017-06-04T00:00:00Z          8         20
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0                muddaub      1        NaN              NaN          1
# ...

# %%
df_SAFI_some_cols = pd.read_csv("data/SAFI_clean.csv", usecols=[0, 1, 2, 11, 12, 13])

# %%
df_SAFI_some_cols
# Out:
#      key_ID   village        interview_date  no_meals  \
# 0         1       God  2016-11-17T00:00:00Z         2
# 1         1       God  2016-11-17T00:00:00Z         2
# 2         3       God  2016-11-17T00:00:00Z         2
# 3         4       God  2016-11-17T00:00:00Z         2
# 4         5       God  2016-11-17T00:00:00Z         2
# ..      ...       ...                   ...       ...
# 126     126     Ruaca  2017-05-18T00:00:00Z         3
# 127     193     Ruaca  2017-06-04T00:00:00Z         3
# 128     194     Ruaca  2017-06-04T00:00:00Z         3
# 129     199  Chirodzo  2017-06-04T00:00:00Z         3
# 130     200  Chirodzo  2017-06-04T00:00:00Z         3
#
#             months_lack_food                                 instanceID
# 0                        Jan  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef
# 1       Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# 2    Jan;Feb;Mar;Oct;Nov;Dec  uuid:193d7daf-9582-409b-bf09-027dd36f9007
# ...

# %%
df_SAFI_some_cols.shape
# Out:
# (131, 6)

# %%
df_SAFI_some_cols.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5bc8f994fc2b> in <module>
# ----> 1 df_SAFI_some_cols.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df_SAFI_some_cols.head()
# Out:
#    key_ID village        interview_date  no_meals         months_lack_food  \
# 0       1     God  2016-11-17T00:00:00Z         2                      Jan
# 1       1     God  2016-11-17T00:00:00Z         2     Jan;Sept;Oct;Nov;Dec
# 2       3     God  2016-11-17T00:00:00Z         2  Jan;Feb;Mar;Oct;Nov;Dec
# 3       4     God  2016-11-17T00:00:00Z         2         Sept;Oct;Nov;Dec
# 4       5     God  2016-11-17T00:00:00Z         2         Aug;Sept;Oct;Nov
#
#                                   instanceID
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# 2  uuid:193d7daf-9582-409b-bf09-027dd36f9007
# 3  uuid:148d1105-778a-4755-aa71-281eadd4a973
# 4  uuid:2c867811-9696-4966-9866-f35c3e97d02d

# %%
df_SAFI_some_cols.columns
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')

# %%
df_SAFI
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# ..      ...       ...                   ...        ...        ...
# 126     126     Ruaca  2017-05-18T00:00:00Z          3          7
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
# 130     200  Chirodzo  2017-06-04T00:00:00Z          8         20
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0                muddaub      1        NaN              NaN          1
# ...

# %%
df_SAFI['village']
# Out:
# 0           God
# 1           God
# 2           God
# 3           God
# 4           God
#          ...
# 126       Ruaca
# 127       Ruaca
# 128       Ruaca
# 129    Chirodzo
# 130    Chirodzo
# Name: village, Length: 131, dtype: object

# %%
df_SAFI.village
# Out:
# 0           God
# 1           God
# 2           God
# 3           God
# 4           God
#          ...
# 126       Ruaca
# 127       Ruaca
# 128       Ruaca
# 129    Chirodzo
# 130    Chirodzo
# Name: village, Length: 131, dtype: object

# %%
df_SAFI[['village', 'interview_date', 'no_membrs']]
# Out:
#       village        interview_date  no_membrs
# 0         God  2016-11-17T00:00:00Z          3
# 1         God  2016-11-17T00:00:00Z          7
# 2         God  2016-11-17T00:00:00Z         10
# 3         God  2016-11-17T00:00:00Z          7
# 4         God  2016-11-17T00:00:00Z          7
# ..        ...                   ...        ...
# 126     Ruaca  2017-05-18T00:00:00Z          3
# 127     Ruaca  2017-06-04T00:00:00Z          7
# 128     Ruaca  2017-06-04T00:00:00Z          4
# 129  Chirodzo  2017-06-04T00:00:00Z          7
# 130  Chirodzo  2017-06-04T00:00:00Z          8
#
# [131 rows x 3 columns]

# %%
select_cols = ['village', 'interview_date', 'no_membrs']

# %%
df_SAFI[select_cols]
# Out:
#       village        interview_date  no_membrs
# 0         God  2016-11-17T00:00:00Z          3
# 1         God  2016-11-17T00:00:00Z          7
# 2         God  2016-11-17T00:00:00Z         10
# 3         God  2016-11-17T00:00:00Z          7
# 4         God  2016-11-17T00:00:00Z          7
# ..        ...                   ...        ...
# 126     Ruaca  2017-05-18T00:00:00Z          3
# 127     Ruaca  2017-06-04T00:00:00Z          7
# 128     Ruaca  2017-06-04T00:00:00Z          4
# 129  Chirodzo  2017-06-04T00:00:00Z          7
# 130  Chirodzo  2017-06-04T00:00:00Z          8
#
# [131 rows x 3 columns]

# %%
df_SAFI[1:4]
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
#
#                                          items_owned  no_meals  \
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
# 2                                        solar_torch         2
# 3  bicycle;radio;cow_plough;solar_panel;mobile_phone         2
#
#           months_lack_food                                 instanceID
# 1     Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# ...

# %%
# %load code/pdindex
# See what happens when you try each of the following:

# 1. List the columns you want out of order from the way they appear in the file?
df_SAFI[['interview_date', 'village']]

# 2. What happens if we put the same column name in twice?
df_SAFI[['village', 'village']]

# 3. What does python do if you use a non-existing column name? (a.k.a Typo)
# df_SAFI[['village', 'v']] # it will give an error

# 4. Use help to figure out how to select a range of columns

# 5. How can you select only the first row?

# 6. What about the last 3 rows?
# Out:
#       village   village
# 0         God       God
# 1         God       God
# 2         God       God
# 3         God       God
# 4         God       God
# ..        ...       ...
# 126     Ruaca     Ruaca
# 127     Ruaca     Ruaca
# 128     Ruaca     Ruaca
# 129  Chirodzo  Chirodzo
# 130  Chirodzo  Chirodzo
#
# [131 rows x 2 columns]

# %%
df_SAFI_some_rows = df_SAFI[df_SAFI.village == "Ruaca"]

# %%
df_SAFI_some_rows
# Out:
#      key_ID village        interview_date  no_membrs  years_liv  \
# 22       23   Ruaca  2016-11-21T00:00:00Z         10         20
# 23       24   Ruaca  2016-11-21T00:00:00Z          6          4
# 24       25   Ruaca  2016-11-21T00:00:00Z         11          6
# 25       26   Ruaca  2016-11-21T00:00:00Z          3         20
# 26       27   Ruaca  2016-11-21T00:00:00Z          7         36
# 27       28   Ruaca  2016-11-21T00:00:00Z          2          2
# 28       29   Ruaca  2016-11-21T00:00:00Z          7         10
# 29       30   Ruaca  2016-11-21T00:00:00Z          7         22
# 30       31   Ruaca  2016-11-21T00:00:00Z          3          2
# 31       32   Ruaca  2016-11-21T00:00:00Z         19         69
# 32       33   Ruaca  2016-11-21T00:00:00Z          8         34
# 70       71   Ruaca  2016-11-18T00:00:00Z          6         14
# 72      133   Ruaca  2016-11-23T00:00:00Z          5         25
# 73      152   Ruaca  2016-11-24T00:00:00Z         10         16
# ...

# %%
# & -- and
# | -- or
df_SAFI_some_rows = df_SAFI[(df_SAFI.village == "Ruaca") & (df_SAFI.no_membrs > 15)]

# %%
df_SAFI_some_rows
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 31      32   Ruaca  2016-11-21T00:00:00Z         19         69
# 91      76   Ruaca  2017-04-26T00:00:00Z         17         48
#
#    respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 31              muddaub      2        yes        more_once          5
# 91          burntbricks      2        yes        more_once          4
#
#                                           items_owned  no_meals  \
# 31  cow_cart;motorcyle;radio;cow_plough;solar_pane...         2
# 91  bicycle;radio;cow_plough;solar_panel;mobile_phone         3
#
#    months_lack_food                                 instanceID
# 31             none  uuid:25597af3-cd79-449c-a48a-fb9aea6c48bf
# 91             none  uuid:4178a296-903a-4a8e-9cfa-0cd6143476e8

# %%
type(df_SAFI_some_rows)
# Out:
# pandas.core.frame.DataFrame

# %%
df_SAFI_some_rows[["village", "years_liv", "rooms"]]
# Out:
#    village  years_liv  rooms
# 31   Ruaca         69      2
# 91   Ruaca         48      2

# %%
df_SAFI.iloc[1:4]
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
#
#                                          items_owned  no_meals  \
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
# 2                                        solar_torch         2
# 3  bicycle;radio;cow_plough;solar_panel;mobile_phone         2
#
#           months_lack_food                                 instanceID
# 1     Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# ...

# %%
df_SAFI.iloc[1:4, 1:4]
# Out:
#   village        interview_date  no_membrs
# 1     God  2016-11-17T00:00:00Z          7
# 2     God  2016-11-17T00:00:00Z         10
# 3     God  2016-11-17T00:00:00Z          7

# %%
df_SAFI.iloc[:, 1:4]
# Out:
#       village        interview_date  no_membrs
# 0         God  2016-11-17T00:00:00Z          3
# 1         God  2016-11-17T00:00:00Z          7
# 2         God  2016-11-17T00:00:00Z         10
# 3         God  2016-11-17T00:00:00Z          7
# 4         God  2016-11-17T00:00:00Z          7
# ..        ...                   ...        ...
# 126     Ruaca  2017-05-18T00:00:00Z          3
# 127     Ruaca  2017-06-04T00:00:00Z          7
# 128     Ruaca  2017-06-04T00:00:00Z          4
# 129  Chirodzo  2017-06-04T00:00:00Z          7
# 130  Chirodzo  2017-06-04T00:00:00Z          8
#
# [131 rows x 3 columns]

# %%
df_SAFI.iloc[:, [1, 4, 10]]
# Out:
#       village  years_liv                                        items_owned
# 0         God          4               bicycle;television;solar_panel;table
# 1         God          9  cow_cart;bicycle;radio;cow_plough;solar_panel;...
# 2         God         15                                        solar_torch
# 3         God          6  bicycle;radio;cow_plough;solar_panel;mobile_phone
# 4         God         40            motorcyle;radio;cow_plough;mobile_phone
# ..        ...        ...                                                ...
# 126     Ruaca          7                        motorcyle;radio;solar_panel
# 127     Ruaca         10  car;lorry;television;radio;sterio;cow_plough;s...
# 128     Ruaca          5         radio;solar_panel;solar_torch;mobile_phone
# 129  Chirodzo         17  cow_cart;lorry;motorcyle;computer;television;r...
# 130  Chirodzo         20  radio;cow_plough;solar_panel;solar_torch;table...
#
# [131 rows x 3 columns]

# %%
df_SAFI.describe()
# Out:
#            key_ID  no_membrs   years_liv       rooms   liv_count    no_meals
# count  131.000000  131.00000  131.000000  131.000000  131.000000  131.000000
# mean    85.473282    7.19084   23.053435    1.740458    2.366412    2.603053
# std     63.151628    3.17227   16.913041    1.092547    1.082775    0.491143
# min      1.000000    2.00000    1.000000    1.000000    1.000000    2.000000
# 25%     32.500000    5.00000   12.000000    1.000000    1.000000    2.000000
# 50%     66.000000    7.00000   20.000000    1.000000    2.000000    3.000000
# 75%    138.000000    9.00000   27.500000    2.000000    3.000000    3.000000
# max    202.000000   19.00000   96.000000    8.000000    5.000000    3.000000

# %%
df_SAFI['no_membrs'].describe()
# Out:
# count    131.00000
# mean       7.19084
# std        3.17227
# min        2.00000
# 25%        5.00000
# 50%        7.00000
# 75%        9.00000
# max       19.00000
# Name: no_membrs, dtype: float64

# %%
df_SAFI['no_membrs'].mean()
# Out:
# 7.190839694656488

# %%
df_SAFI.groupby('village').describe()
# Out:
#          key_ID                                                          \
#           count        mean        std   min   25%    50%    75%    max
# village
# Chirodzo   39.0   62.487179  44.261705   8.0  44.5   55.0   64.5  200.0
# God        43.0   81.720930  77.863839   1.0  14.5   40.0  168.5  202.0
# Ruaca      49.0  107.061224  55.024013  23.0  72.0  113.0  152.0  194.0
#
#          no_membrs            ... liv_count      no_meals                      \
#              count      mean  ...       75%  max    count      mean       std
# village                       ...
# Chirodzo      39.0  7.076923  ...       3.0  4.0     39.0  2.615385  0.492864
# God           43.0  6.860465  ...       3.0  4.0     43.0  2.558140  0.502486
# Ruaca         49.0  7.571429  ...       3.0  5.0     49.0  2.632653  0.487078
#
#
#           min  25%  50%  75%  max
# village
# Chirodzo  2.0  2.0  3.0  3.0  3.0
# God       2.0  2.0  3.0  3.0  3.0
# Ruaca     2.0  2.0  3.0  3.0  3.0
#
# ...

# %%
df_SAFI.groupby(["village", "respondent_wall_type"])["no_membrs"].mean().reset_index()
# Out:
#      village respondent_wall_type  no_membrs
# 0   Chirodzo          burntbricks   8.181818
# 1   Chirodzo              muddaub   5.625000
# 2   Chirodzo            sunbricks   6.000000
# 3        God          burntbricks   8.500000
# 4        God              muddaub   7.000000
# 5        God          burntbricks   7.352941
# 6        God              muddaub   5.357143
# 7        God            sunbricks   7.888889
# 8      Ruaca          burntbricks   7.730769
# 9      Ruaca               cement   7.000000
# 10     Ruaca              muddaub   7.000000
# 11     Ruaca            sunbricks   8.285714

# %%
# %load code/groupby
# 1. Read in the SAFI_clean.csv dataset.
# 2. Get a list of the different `rooms` values.
# 3. Groupby `rooms` and describe the results.
# 4. Remove all rows with NaN values.
# 5. repeat steps 2 & 3 and compare the results.

# %%
df_SAFI = pd.read_csv("data/SAFI_clean.csv")

# %%
df_SAFI['rooms']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 126    1
# 127    3
# 128    1
# 129    2
# 130    2
# Name: rooms, Length: 131, dtype: int64

# %%
pd.unique(df_SAFI['rooms'])
# Out:
# array([1, 3, 5, 2, 4, 8], dtype=int64)

# %%
df_SAFI.groupby('rooms').describe()
# Out:
#       key_ID                                                            \
#        count        mean        std    min    25%    50%    75%    max
# rooms
# 1       73.0   78.958904  61.534416    1.0   33.0   61.0  125.0  198.0
# 2       33.0  100.515152  66.276938   15.0   46.0   76.0  174.0  201.0
# 3       17.0   70.352941  55.865845    8.0   25.0   59.0  110.0  193.0
# 4        5.0  135.400000  71.716804   23.0  117.0  144.0  191.0  202.0
# 5        2.0   58.000000  67.882251   10.0   34.0   58.0   82.0  106.0
# 8        1.0  127.000000        NaN  127.0  127.0  127.0  127.0  127.0
#
#       no_membrs             ... liv_count      no_meals                      \
#           count       mean  ...       75%  max    count      mean       std
# rooms                       ...
# 1          73.0   6.205479  ...       3.0  5.0     73.0  2.589041  0.495413
# 2          33.0   8.090909  ...       3.0  5.0     33.0  2.636364  0.488504
# ...

# %%
df_SAFI_complete = df_SAFI.dropna()

# %%
df_SAFI_complete
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# ..      ...       ...                   ...        ...        ...
# 125     192  Chirodzo  2017-06-03T00:00:00Z          9         20
# 126     126     Ruaca  2017-05-18T00:00:00Z          3          7
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1                muddaub      1        yes             once          3
# ...

# %%
df_SAFI_complete.groupby("rooms").describe()
# Out:
#       key_ID                                                             \
#        count        mean        std    min     25%    50%    75%    max
# rooms
# 1       44.0   98.295455  60.959605    1.0   44.50   84.0  160.5  195.0
# 2       25.0  104.840000  63.948339   15.0   56.00   89.0  174.0  199.0
# 3       14.0   71.928571  58.515566    8.0   27.25   61.5   99.5  193.0
# 4        3.0  179.000000  30.805844  144.0  167.50  191.0  196.5  202.0
# 5        2.0   58.000000  67.882251   10.0   34.00   58.0   82.0  106.0
#
#       no_membrs             ... liv_count      no_meals                      \
#           count       mean  ...       75%  max    count      mean       std
# rooms                       ...
# 1          44.0   6.886364  ...       3.0  5.0     44.0  2.659091  0.479495
# 2          25.0   8.520000  ...       4.0  5.0     25.0  2.640000  0.489898
# 3          14.0   8.928571  ...       3.0  4.0     14.0  2.571429  0.513553
# ...
