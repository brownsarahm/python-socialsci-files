# %% [markdown]
# # Plotting

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
safi_df = pd.read_csv("data/SAFI_full_shortname.csv")
safi_df.head()
# Out:
#    key_id    interview_date  quest_no                     start  \
# 0       1  17 November 2016         1  2017-03-23T09:49:57.000Z
# 1       2  17 November 2016         1  2017-04-02T09:48:16.000Z
# 2       3  17 November 2016         3  2017-04-02T14:35:26.000Z
# 3       4  17 November 2016         4  2017-04-02T14:55:18.000Z
# 4       5  17 November 2016         5  2017-04-02T15:10:35.000Z
#
#                         end province district     ward village  years_farm  \
# 0  2017-04-02T17:29:08.000Z   Manica   Manica  Bandula     God          11
# 1  2017-04-02T17:26:19.000Z   Manica   Manica  Bandula     God           2
# 2  2017-04-02T17:26:53.000Z   Manica   Manica  Bandula     God          40
# 3  2017-04-02T17:27:16.000Z   Manica   Manica  Bandula     God           6
# 4  2017-04-02T17:27:35.000Z   Manica   Manica  Bandula     God          18
#
#                      ...                      \
# 0                    ...
# 1                    ...
# 2                    ...
# ...

# %%
safi_df.dtypes
# Out:
# key_id                          int64
# interview_date                 object
# quest_no                        int64
# start                          object
# end                            object
# province                       object
# district                       object
# ward                           object
# village                        object
# years_farm                      int64
# agr_assoc                      object
# _note2                        float64
# no_membrs                       int64
# _members_count                  int64
# remittance_money               object
# years_liv                       int64
# parents_liv                    object
# sp_parents_liv                 object
# grand_liv                      object
# sp_grand_liv                   object
# respondent_roof_type           object
# respondent_wall_type           object
# respondent_wall_type_other    float64
# respondent_floor_type          object
# window_type                    object
# ...

# %%
safi_df['years_liv'].hist()

# %%
safi_df['years_liv'].hist(bins=20)

# %%
safi_df.hist(column='years_liv',by='village',layout =(1,3), figsize=(12,3),sharex=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f94eb195dd8>,
# ...
#       dtype=object)

# %%
safi_df.plot.scatter(x='gps_Latitude', y='gps_Longitude', c='gps_Altitude', colormap="viridis", figsize=[10,10])

# %%
safi_df.plot.scatter(x='years_farm', y='years_liv', c='buildings_in_compound', colormap="viridis", figsize=[10,10]);

# %%
safi_df.boxplot(by ='village',column=['buildings_in_compound'])

# %%
import seaborn as sns

# %%
sns.boxplot(data=safi_df,x ='village',y='buildings_in_compound')

# %%
sns.lmplot(x='years_farm', y='years_liv',data=safi_df,hue='village')

# %%
sns.lmplot(x='no_plots', y='liv_count',data=safi_df,hue='village',x_jitter = .2,y_jitter=.2)
