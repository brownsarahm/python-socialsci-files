# %% [markdown]
# # Episode 09 - Extracting Data

# %%
import pandas as pd
df_SAFI = pd.read_csv("../data/SAFI_clean.csv")
df_SAFI.columns
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')

# %% [markdown]
# ## Selecting rows and columns from a pandas Dataframe

# %%
df_SAFI_some_cols = pd.read_csv("../data/SAFI_clean.csv", usecols=[0,1,2,11,12,13])
print(df_SAFI_some_cols.shape)
print(df_SAFI_some_cols.columns)
# Out:
# (131, 6)
# Index(['key_ID', 'village', 'interview_date', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')

# %%
print(df_SAFI['village'])
# Out:
# 0           God
# 1           God
# 2           God
# 3           God
# 4           God
# 5           God
# 6           God
# 7      Chirodzo
# 8      Chirodzo
# 9      Chirodzo
# 10          God
# 11          God
# 12          God
# 13          God
# 14          God
# 15          God
# 16          God
# 17          God
# 18          God
# 19          God
# 20          God
# 21          God
# 22        Ruaca
# 23        Ruaca
# 24        Ruaca
# 25        Ruaca
# 26        Ruaca
# 27        Ruaca
# 28        Ruaca
# 29        Ruaca
#          ...
# 101       Ruaca
# 102         God
# 103         God
# 104       Ruaca
# 105       Ruaca
# 106       Ruaca
# 107       Ruaca
# 108       Ruaca
# 109       Ruaca
# 110         God
# 111       Ruaca
# 112       Ruaca
# 113       Ruaca
# 114       Ruaca
# 115       Ruaca
# 116         God
# 117         God
# 118       Ruaca
# 119       Ruaca
# 120       Ruaca
# 121       Ruaca
# 122       Ruaca
# 123       Ruaca
# 124       Ruaca
# ...

# %%
print(df_SAFI.village)
# Out:
# 0           God
# 1           God
# 2           God
# 3           God
# 4           God
# 5           God
# 6           God
# 7      Chirodzo
# 8      Chirodzo
# 9      Chirodzo
# 10          God
# 11          God
# 12          God
# 13          God
# 14          God
# 15          God
# 16          God
# 17          God
# 18          God
# 19          God
# 20          God
# 21          God
# 22        Ruaca
# 23        Ruaca
# 24        Ruaca
# 25        Ruaca
# 26        Ruaca
# 27        Ruaca
# 28        Ruaca
# 29        Ruaca
#          ...
# 101       Ruaca
# 102         God
# 103         God
# 104       Ruaca
# 105       Ruaca
# 106       Ruaca
# 107       Ruaca
# 108       Ruaca
# 109       Ruaca
# 110         God
# 111       Ruaca
# 112       Ruaca
# 113       Ruaca
# 114       Ruaca
# 115       Ruaca
# 116         God
# 117         God
# 118       Ruaca
# 119       Ruaca
# 120       Ruaca
# 121       Ruaca
# 122       Ruaca
# 123       Ruaca
# 124       Ruaca
# ...

# %%
print(df_SAFI[['village', 'interview_date', 'no_membrs']])
# Out:
#       village        interview_date  no_membrs
# 0         God  2016-11-17T00:00:00Z          3
# 1         God  2016-11-17T00:00:00Z          7
# 2         God  2016-11-17T00:00:00Z         10
# 3         God  2016-11-17T00:00:00Z          7
# 4         God  2016-11-17T00:00:00Z          7
# 5         God  2016-11-17T00:00:00Z          3
# 6         God  2016-11-17T00:00:00Z          6
# 7    Chirodzo  2016-11-16T00:00:00Z         12
# 8    Chirodzo  2016-11-16T00:00:00Z          8
# 9    Chirodzo  2016-12-16T00:00:00Z         12
# 10        God  2016-11-21T00:00:00Z          6
# 11        God  2016-11-21T00:00:00Z          7
# 12        God  2016-11-21T00:00:00Z          6
# 13        God  2016-11-21T00:00:00Z         10
# 14        God  2016-11-21T00:00:00Z          5
# 15        God  2016-11-24T00:00:00Z          6
# 16        God  2016-11-21T00:00:00Z          8
# 17        God  2016-11-21T00:00:00Z          4
# 18        God  2016-11-21T00:00:00Z          9
# ...

# %% [markdown]
# ### Filtering by rows

# %%
# select row with index of 1, 2 and 3 (rows 2, 3 and 4 in the Dataframe)
df_SAFI_some_rows = df_SAFI[1:4]
df_SAFI_some_rows
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
#
#                                          items_owned  no_meals  \
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
# 2                                        solar_torch         2
# 3  bicycle;radio;cow_plough;solar_panel;mobile_phone         2
#
#           months_lack_food                                 instanceID
# 1     Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# ...

# %% [markdown]
# ## Exercise 09-01 pdindex

# %%
# %load ../code/pdindex.py
See what happens when you try each of the following:

1. List the columns you want out of order from the way they appear in the file?
2. What happens if we put the same column name in twice?
3. What does python do if you use a non-existing column name? (a.k.a Typo)
4. Use help to figure out how to select a range of columns
5. How can you select only the first row?
6. What about the last 3 rows?

# %%
# 1.
df_SAFI[['no_membrs', 'village']]
# Out:
#      no_membrs   village
# 1            7       God
# 6            6       God
# 7           12  Chirodzo
# 8            8  Chirodzo
# 9           12  Chirodzo
# 11           7       God
# 12           6       God
# 14           5       God
# 23           6     Ruaca
# 24          11     Ruaca
# 25           3     Ruaca
# 28           7     Ruaca
# 31          19     Ruaca
# 32           8     Ruaca
# 33           8  Chirodzo
# 34           5  Chirodzo
# 35           6  Chirodzo
# 37          10       God
# 39           9       God
# 41           8       God
# 42           7  Chirodzo
# 44           9  Chirodzo
# 45          10  Chirodzo
# 46           2  Chirodzo
# 49           6  Chirodzo
# 51          11  Chirodzo
# 52           8  Chirodzo
# 55          12  Chirodzo
# 56           4  Chirodzo
# 57          11  Chirodzo
# ..         ...       ...
# 95           3       God
# 96           6     Ruaca
# 97          12     Ruaca
# 98           6     Ruaca
# 99           5     Ruaca
# ...

# %%
# 2.
df_SAFI[['no_membrs', 'village', 'no_membrs']]
# Out:
#      no_membrs   village  no_membrs
# 1            7       God          7
# 6            6       God          6
# 7           12  Chirodzo         12
# 8            8  Chirodzo          8
# 9           12  Chirodzo         12
# 11           7       God          7
# 12           6       God          6
# 14           5       God          5
# 23           6     Ruaca          6
# 24          11     Ruaca         11
# 25           3     Ruaca          3
# 28           7     Ruaca          7
# 31          19     Ruaca         19
# 32           8     Ruaca          8
# 33           8  Chirodzo          8
# 34           5  Chirodzo          5
# 35           6  Chirodzo          6
# 37          10       God         10
# 39           9       God          9
# 41           8       God          8
# 42           7  Chirodzo          7
# 44           9  Chirodzo          9
# 45          10  Chirodzo         10
# 46           2  Chirodzo          2
# 49           6  Chirodzo          6
# ...

# %%
# 3.
df_SAFI[['no_members', 'village']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-41883b8f212e> in <module>()
#       1 # 3.
# ----> 2 df_SAFI[['no_members', 'village']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...

# %%
# 4.
df_SAFI.iloc[:,2:5]
# Out:
#            interview_date  no_membrs  years_liv
# 1    2016-11-17T00:00:00Z          7          9
# 6    2016-11-17T00:00:00Z          6         38
# 7    2016-11-16T00:00:00Z         12         70
# 8    2016-11-16T00:00:00Z          8          6
# 9    2016-12-16T00:00:00Z         12         23
# 11   2016-11-21T00:00:00Z          7         20
# 12   2016-11-21T00:00:00Z          6          8
# 14   2016-11-21T00:00:00Z          5         30
# 23   2016-11-21T00:00:00Z          6          4
# 24   2016-11-21T00:00:00Z         11          6
# 25   2016-11-21T00:00:00Z          3         20
# 28   2016-11-21T00:00:00Z          7         10
# 31   2016-11-21T00:00:00Z         19         69
# 32   2016-11-21T00:00:00Z          8         34
# 33   2016-11-17T00:00:00Z          8         18
# 34   2016-11-17T00:00:00Z          5         45
# 35   2016-11-17T00:00:00Z          6         23
# 37   2016-11-17T00:00:00Z         10         19
# 39   2016-11-17T00:00:00Z          9         23
# ...

# %%
# 5. 
df_SAFI[0:1]
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 1       1     God  2016-11-17T00:00:00Z          7          9
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1              muddaub      1        yes             once          3
#
#                                          items_owned  no_meals  \
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
#
#        months_lack_food                                 instanceID
# 1  Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e

# %%
# 6.
df_SAFI[len(df_SAFI.village)-3:]
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 127               cement      3         no        more_once          3
# 128              muddaub      1         no        more_once          1
# 129          burntbricks      2        yes        more_once          2
#
#                                            items_owned  no_meals  \
# 127  car;lorry;television;radio;sterio;cow_plough;s...         3
# 128         radio;solar_panel;solar_torch;mobile_phone         3
# 129  cow_cart;lorry;motorcyle;computer;television;r...         3
#
#     months_lack_food                                 instanceID
# 127             none  uuid:5ccc2e5a-ea90-48b5-8542-69400d5334df
# ...

# %%
# 6. alternative
df_SAFI.tail(3)
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 127     193     Ruaca  2017-06-04T00:00:00Z          7         10
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 127               cement      3         no        more_once          3
# 128              muddaub      1         no        more_once          1
# 129          burntbricks      2        yes        more_once          2
#
#                                            items_owned  no_meals  \
# 127  car;lorry;television;radio;sterio;cow_plough;s...         3
# 128         radio;solar_panel;solar_torch;mobile_phone         3
# 129  cow_cart;lorry;motorcyle;computer;television;r...         3
#
#     months_lack_food                                 instanceID
# 127             none  uuid:5ccc2e5a-ea90-48b5-8542-69400d5334df
# ...

# %% [markdown]
# ### Using criteria to filter rows

# %%
df_SAFI_some_rows = df_SAFI[(df_SAFI.village == 'Ruaca')]
df_SAFI_some_rows
# Out:
#      key_ID village        interview_date  no_membrs  years_liv  \
# 22       23   Ruaca  2016-11-21T00:00:00Z         10         20
# 23       24   Ruaca  2016-11-21T00:00:00Z          6          4
# 24       25   Ruaca  2016-11-21T00:00:00Z         11          6
# 25       26   Ruaca  2016-11-21T00:00:00Z          3         20
# 26       27   Ruaca  2016-11-21T00:00:00Z          7         36
# 27       28   Ruaca  2016-11-21T00:00:00Z          2          2
# 28       29   Ruaca  2016-11-21T00:00:00Z          7         10
# 29       30   Ruaca  2016-11-21T00:00:00Z          7         22
# 30       31   Ruaca  2016-11-21T00:00:00Z          3          2
# 31       32   Ruaca  2016-11-21T00:00:00Z         19         69
# 32       33   Ruaca  2016-11-21T00:00:00Z          8         34
# 70       71   Ruaca  2016-11-18T00:00:00Z          6         14
# 72      133   Ruaca  2016-11-23T00:00:00Z          5         25
# 73      152   Ruaca  2016-11-24T00:00:00Z         10         16
# ...

# %%
df_SAFI_some_rows = df_SAFI[ (df_SAFI.village == 'Ruaca') & (df_SAFI.no_membrs > 15)]
df_SAFI_some_rows
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 31      32   Ruaca  2016-11-21T00:00:00Z         19         69
# 91      76   Ruaca  2017-04-26T00:00:00Z         17         48
#
#    respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 31              muddaub      2        yes        more_once          5
# 91          burntbricks      2        yes        more_once          4
#
#                                           items_owned  no_meals  \
# 31  cow_cart;motorcyle;radio;cow_plough;solar_pane...         2
# 91  bicycle;radio;cow_plough;solar_panel;mobile_phone         3
#
#    months_lack_food                                 instanceID
# 31             none  uuid:25597af3-cd79-449c-a48a-fb9aea6c48bf
# 91             none  uuid:4178a296-903a-4a8e-9cfa-0cd6143476e8

# %%
df_SAFI_some_rows = df_SAFI[ (df_SAFI.village == 'Ruaca') & (df_SAFI.no_membrs > 15)][['village', 'years_liv','rooms']]
df_SAFI_some_rows
# Out:
#    village  years_liv  rooms
# 31   Ruaca         69      2
# 91   Ruaca         48      2

# %%
df_SAFI_some_rows = df_SAFI.iloc[1:4]
df_SAFI_some_rows
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
#
#                                          items_owned  no_meals  \
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
# 2                                        solar_torch         2
# 3  bicycle;radio;cow_plough;solar_panel;mobile_phone         2
#
#           months_lack_food                                 instanceID
# 1     Jan;Sept;Oct;Nov;Dec  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# ...

# %%
# Select the first row from the Dataframe
df_SAFI_some_rows = df_SAFI.iloc[0]
df_SAFI_some_rows
# Out:
# key_ID                                                          1
# village                                                       God
# interview_date                               2016-11-17T00:00:00Z
# no_membrs                                                       3
# years_liv                                                       4
# respondent_wall_type                                      muddaub
# rooms                                                           1
# memb_assoc                                                    NaN
# affect_conflicts                                              NaN
# liv_count                                                       1
# items_owned                  bicycle;television;solar_panel;table
# no_meals                                                        2
# months_lack_food                                              Jan
# instanceID              uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef
# Name: 0, dtype: object

# %%
# select every 20th record from the Dataframe.
df_SAFI_some_rows = df_SAFI.iloc[range(0, len(df_SAFI), 20)]
df_SAFI_some_rows
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 20       21       God  2016-11-21T00:00:00Z          8         20
# 40       41       God  2016-11-17T00:00:00Z          7         22
# 60       61  Chirodzo  2016-11-16T00:00:00Z         10         14
# 80      182       God  2016-11-25T00:00:00Z          7         21
# 100     104     Ruaca  2017-04-28T00:00:00Z         14         52
# 120     167     Ruaca  2017-06-03T00:00:00Z          8         24
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0                muddaub      1        NaN              NaN          1
# 20           burntbricks      1         no            never          3
# 40               muddaub      1        NaN              NaN          2
# 60               muddaub      1        yes        more_once          3
# 80               muddaub      3         no        more_once          2
# ...

# %%
# columns 0,1,2 and 3
df_SAFI_some_rows = df_SAFI.iloc[range(0, len(df_SAFI), 20),0:4]
df_SAFI_some_rows
# Out:
#      key_ID   village        interview_date  no_membrs
# 0         1       God  2016-11-17T00:00:00Z          3
# 20       21       God  2016-11-21T00:00:00Z          8
# 40       41       God  2016-11-17T00:00:00Z          7
# 60       61  Chirodzo  2016-11-16T00:00:00Z         10
# 80      182       God  2016-11-25T00:00:00Z          7
# 100     104     Ruaca  2017-04-28T00:00:00Z         14
# 120     167     Ruaca  2017-06-03T00:00:00Z          8

# %%
# columns 0,1,6 and 12
df_SAFI_some_rows = df_SAFI.iloc[range(0, len(df_SAFI), 20),[0,1,6,12]]
df_SAFI_some_rows
# Out:
#      key_ID   village  rooms         months_lack_food
# 0         1       God      1                      Jan
# 20       21       God      1  Jan;Feb;Mar;Oct;Nov;Dec
# 40       41       God      1                  Oct;Nov
# 60       61  Chirodzo      1              Jan;Feb;Dec
# 80      182       God      3          Jan;Feb;Nov;Dec
# 100     104     Ruaca      1              Jan;Feb;Dec
# 120     167     Ruaca      1              Jan;Nov;Dec

# %%
# columns 0,1,6 and 12 using the column names and changing 'iloc' to 'loc'
df_SAFI_some_rows = df_SAFI.loc[range(0, len(df_SAFI), 20),['key_ID', 'village', 'rooms', 'months_lack_food']]
df_SAFI_some_rows
# Out:
#      key_ID   village  rooms         months_lack_food
# 0         1       God      1                      Jan
# 20       21       God      1  Jan;Feb;Mar;Oct;Nov;Dec
# 40       41       God      1                  Oct;Nov
# 60       61  Chirodzo      1              Jan;Feb;Dec
# 80      182       God      3          Jan;Feb;Nov;Dec
# 100     104     Ruaca      1              Jan;Feb;Dec
# 120     167     Ruaca      1              Jan;Nov;Dec

# %% [markdown]
# ### Sampling

# %%
# ten records, do not select same record twice (this is the default)
df_SAFI.sample(10, replace=False)
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 50       51  Chirodzo  2016-11-16T00:00:00Z          5         30
# 25       26     Ruaca  2016-11-21T00:00:00Z          3         20
# 88      202       God  2016-11-17T00:00:00Z         12         12
# 99       80     Ruaca  2017-04-28T00:00:00Z          5         12
# 71      127  Chirodzo  2016-11-16T00:00:00Z          4         18
# 46       47  Chirodzo  2016-11-17T00:00:00Z          2          2
# 17       18       God  2016-11-21T00:00:00Z          4         20
# 80      182       God  2016-11-25T00:00:00Z          7         21
# 44       45  Chirodzo  2016-11-17T00:00:00Z          9          7
# 110     108       God  2017-05-11T00:00:00Z         15         22
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 50               muddaub      1        NaN              NaN          1
# 25           burntbricks      2         no            never          2
# ...

# %%
# 5% of records , same records if run again
df_SAFI.sample(frac=0.05, random_state=1)
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 42       43  Chirodzo  2016-11-17T00:00:00Z          7         29
# 80      182       God  2016-11-25T00:00:00Z          7         21
# 128     194     Ruaca  2017-06-04T00:00:00Z          4          5
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 44       45  Chirodzo  2016-11-17T00:00:00Z          9          7
# 75      155       God  2016-11-24T00:00:00Z          4          4
# 102     106       God  2017-04-30T00:00:00Z         15         22
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 42               muddaub      1         no            never          2
# 80               muddaub      3         no        more_once          2
# 128              muddaub      1         no        more_once          1
# 5                muddaub      1        NaN              NaN          1
# 44               muddaub      1         no            never          4
# ...

# %% [markdown]
# # Episode 10 - aggregations

# %% [markdown]
# ## Using Pandas functions to summarise data in a Data Frame

# %%
import pandas as pd
df_SAFI = pd.read_csv("../data/SAFI_clean.csv")
df_SAFI
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %%
df_SAFI.describe()
# Out:
#            key_ID  no_membrs   years_liv       rooms   liv_count    no_meals
# count  131.000000  131.00000  131.000000  131.000000  131.000000  131.000000
# mean    85.473282    7.19084   23.053435    1.740458    2.366412    2.603053
# std     63.151628    3.17227   16.913041    1.092547    1.082775    0.491143
# min      1.000000    2.00000    1.000000    1.000000    1.000000    2.000000
# 25%     32.500000    5.00000   12.000000    1.000000    1.000000    2.000000
# 50%     66.000000    7.00000   20.000000    1.000000    2.000000    3.000000
# 75%    138.000000    9.00000   27.500000    2.000000    3.000000    3.000000
# max    202.000000   19.00000   96.000000    8.000000    5.000000    3.000000

# %%
df_SAFI['no_membrs'].describe()
# Out:
# count    131.00000
# mean       7.19084
# std        3.17227
# min        2.00000
# 25%        5.00000
# 50%        7.00000
# 75%        9.00000
# max       19.00000
# Name: no_membrs, dtype: float64

# %% [markdown]
# ## Categorical variables

# %%
pd.unique(df_SAFI['respondent_wall_type'])
# Out:
# array(['muddaub', ' muddaub', ' burntbricks', 'burntbricks', 'sunbricks',
#        'cement'], dtype=object)

# %%
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
pd.unique(df_SAFI['respondent_wall_type'])
# Out:
# array(['muddaub', 'burntbricks', 'sunbricks', 'cement'], dtype=object)

# %%
df_SAFI['respondent_wall_type'].count()
# Out:
# 131

# %% [markdown]
# ## Exercise 10-01 counts

# %%
# %load ../code/counts.py
1. Get the unique entries for the `affect_conflicts` variable
2. Get the count value for `affect_conflicts` and compare it with the count for `respondent_wall_type`.
3. Why do you think they are different?

# %%
# 1.
print(pd.unique(df_SAFI['affect_conflicts']))
# Out:
# [nan 'once' 'never' 'more_once' 'frequently']

# %%
# 2.
print(df_SAFI['affect_conflicts'].count())
# Out:
# 92

# %%
# 3.
df_SAFI['affect_conflicts']
# Out:
# 0             NaN
# 1            once
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6           never
# 7           never
# 8           never
# 9           never
# 10            NaN
# 11          never
# 12          never
# 13            NaN
# 14           once
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20          never
# 21            NaN
# 22            NaN
# 23          never
# 24          never
# 25          never
# 26            NaN
# 27      more_once
# 28     frequently
# 29            NaN
#           ...
# 101    frequently
# 102         never
# 103           NaN
# 104         never
# 105         never
# 106           NaN
# 107     more_once
# 108         never
# 109           NaN
# 110         never
# 111           NaN
# 112           NaN
# 113    frequently
# 114    frequently
# 115         never
# 116         never
# 117    frequently
# 118         never
# 119         never
# ...

# %% [markdown]
# ## Dealing with missing values

# %%
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
df_SAFI.isna().sum()
# Out:
# key_ID                   0
# village                  0
# interview_date           0
# no_membrs                0
# years_liv                0
# respondent_wall_type     0
# rooms                    0
# memb_assoc              39
# affect_conflicts        39
# liv_count                0
# items_owned             10
# no_meals                 0
# months_lack_food         0
# instanceID               0
# dtype: int64

# %%
df_SAFI['affect_conflicts'].isna().sum()
# Out:
# 39

# %% [markdown]
# ### Completely remove rows with NaNs

# %%
print(df_SAFI.shape)
df_SAFI.dropna(inplace=True)
print(df_SAFI.shape)
# Out:
# (131, 14)
# (88, 14)

# %%
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
print(df_SAFI.shape)
df_SAFI.dropna(subset = ['items_owned'], inplace=True)
print(df_SAFI.shape)
# Out:
# (131, 14)
# (121, 14)

# %% [markdown]
# ### Replace NaN with a value of our choice

# %%
import numpy as np
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
df_SAFI.affect_conflicts.replace(to_replace=np.NaN, value='no_response', inplace=True)
df_SAFI
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %% [markdown]
# ### Replace specific values with NaN

# %%
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
df_SAFI.affect_conflicts.replace(to_replace='no_response', value=np.NaN, inplace=True)
df_SAFI
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %% [markdown]
# ## Aggregating data

# %%
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)
grouped_data = df_SAFI.groupby('respondent_wall_type')
grouped_data.describe()
# Out:
#                      key_ID                                              \
#                       count        mean        std    min    25%    50%
# respondent_wall_type
# burntbricks            67.0   88.462687  65.756974    3.0   26.5   70.0
# cement                  1.0  193.000000        NaN  193.0  193.0  193.0
# muddaub                46.0   74.195652  59.332816    1.0   33.5   52.5
# sunbricks              17.0   97.882353  58.109683   11.0   42.0  105.0
#
#                                    liv_count            ...  rooms       \
#                         75%    max     count      mean  ...    75%  max
# respondent_wall_type                                    ...
# burntbricks           148.0  202.0      67.0  2.582090  ...    3.0  8.0
# cement                193.0  193.0       1.0  3.000000  ...    3.0  3.0
# muddaub               113.0  201.0      46.0  1.934783  ...    1.0  4.0
# sunbricks             115.0  189.0      17.0  2.647059  ...    2.0  5.0
#
# ...

# %%
grouped_data = df_SAFI.groupby(['respondent_wall_type', 'village'])
grouped_data.describe()
# Out:
#                               key_ID                                        \
#                                count        mean        std    min     25%
# respondent_wall_type village
# burntbricks          Chirodzo   22.0   70.500000  57.579552    8.0   39.25
#                      God        19.0   86.894737  83.121661    3.0   13.50
#                      Ruaca      26.0  104.807692  55.606488   23.0   71.50
# cement               Ruaca       1.0  193.000000        NaN  193.0  193.00
# muddaub              Chirodzo   16.0   53.125000   9.330059   35.0   46.50
#                      God        15.0   69.733333  78.443307    1.0   11.50
#                      Ruaca      15.0  101.133333  61.340812   28.0   32.50
# sunbricks            Chirodzo    1.0   36.000000        NaN   36.0   36.00
#                      God         9.0   90.777778  71.345599   11.0   17.00
#                      Ruaca       7.0  115.857143  33.567984   85.0  103.50
#
# ...

# %%
no_membrs = df_SAFI.groupby(['village', 'respondent_wall_type'])['no_membrs'].mean()
no_membrs
# Out:
# village   respondent_wall_type
# Chirodzo  burntbricks             8.181818
#           muddaub                 5.625000
#           sunbricks               6.000000
# God       burntbricks             7.473684
#           muddaub                 5.466667
#           sunbricks               7.888889
# Ruaca     burntbricks             7.730769
#           cement                  7.000000
#           muddaub                 7.000000
#           sunbricks               8.285714
# Name: no_membrs, dtype: float64

# %% [markdown]
# ## Exercise 10-02 groupby

# %%
# %load ../code/groupby.py
1. Read in the SAFI_clean.csv dataset.
2. Get a list of the different `rooms` values.
3. Groupby `rooms` and describe the results.
4. Remove all rows with NaN values.
5. repeat steps 2 & 3 and compare the results.

# %%
# 1.
df_SAFI = pd.read_csv('../data/SAFI_clean.csv', skipinitialspace=True)

# %%
# 2.
print(df_SAFI.shape)
print(pd.unique(df_SAFI['rooms']))
# Out:
# (131, 14)
# [1 3 5 2 4 8]

# %%
# 3.
grouped_data = df_SAFI.groupby('rooms')
grouped_data.describe()
# Out:
#       key_ID                                                            \
#        count        mean        std    min    25%    50%    75%    max
# rooms
# 1       73.0   78.958904  61.534416    1.0   33.0   61.0  125.0  198.0
# 2       33.0  100.515152  66.276938   15.0   46.0   76.0  174.0  201.0
# 3       17.0   70.352941  55.865845    8.0   25.0   59.0  110.0  193.0
# 4        5.0  135.400000  71.716804   23.0  117.0  144.0  191.0  202.0
# 5        2.0   58.000000  67.882251   10.0   34.0   58.0   82.0  106.0
# 8        1.0  127.000000        NaN  127.0  127.0  127.0  127.0  127.0
#
#       liv_count            ...  no_membrs       years_liv             \
#           count      mean  ...        75%   max     count       mean
# rooms                      ...
# 1          73.0  2.068493  ...       7.00  15.0      73.0  21.095890
# 2          33.0  2.848485  ...      10.00  19.0      33.0  26.181818
# 3          17.0  2.823529  ...      11.00  12.0      17.0  28.411765
# ...

# %%
# 4.
df_SAFI.dropna(inplace=True)

# %%
# 5.
print(df_SAFI.shape)
print(pd.unique(df_SAFI['rooms']))
# Out:
# (88, 14)
# [1 3 5 2 4]

# %%
grouped_data = df_SAFI.groupby('rooms')
grouped_data.describe()
# Out:
#       key_ID                                                             \
#        count        mean        std    min     25%    50%    75%    max
# rooms
# 1       44.0   98.295455  60.959605    1.0   44.50   84.0  160.5  195.0
# 2       25.0  104.840000  63.948339   15.0   56.00   89.0  174.0  199.0
# 3       14.0   71.928571  58.515566    8.0   27.25   61.5   99.5  193.0
# 4        3.0  179.000000  30.805844  144.0  167.50  191.0  196.5  202.0
# 5        2.0   58.000000  67.882251   10.0   34.00   58.0   82.0  106.0
#
#       liv_count            ...  no_membrs       years_liv             \
#           count      mean  ...        75%   max     count       mean
# rooms                      ...
# 1          44.0  2.318182  ...       8.25  15.0      44.0  23.000000
# 2          25.0  3.080000  ...      11.00  19.0      25.0  27.680000
# 3          14.0  2.785714  ...      11.00  12.0      14.0  27.000000
# 4           3.0  2.666667  ...      11.00  12.0       3.0   7.333333
# ...

# %% [markdown]
# # Episode 11 - joins

# %% [markdown]
# ## Scenario 1 - Two data sets containing the same columns but different rows of data

# %%
import pandas as pd
SAFI_God = pd.read_csv("../data/SAFI_God.csv")
SAFI_Ruaca = pd.read_csv("../data/SAFI_Ruaca.csv")

# %%
print(SAFI_God.head())
print(SAFI_Ruaca.head())
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0       1     God  2016-11-17T00:00:00Z          3          4
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
# 4       5     God  2016-11-17T00:00:00Z          7         40
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0              muddaub      1        NaN              NaN          1
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
# 4          burntbricks      1        NaN              NaN          4
#
#                                          items_owned  no_meals  \
# 0               bicycle;television;solar_panel;table         2
# ...

# %%
print(SAFI_God.columns)
print(SAFI_Ruaca.columns)
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')

# %%
SAFI_allRows = pd.concat([SAFI_God, SAFI_Ruaca])
SAFI_allRows
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 0        1     God  2016-11-17T00:00:00Z          3          4
# 1        1     God  2016-11-17T00:00:00Z          7          9
# 2        3     God  2016-11-17T00:00:00Z         10         15
# 3        4     God  2016-11-17T00:00:00Z          7          6
# 4        5     God  2016-11-17T00:00:00Z          7         40
# 5        6     God  2016-11-17T00:00:00Z          3          3
# 6        7     God  2016-11-17T00:00:00Z          6         38
# 7       11     God  2016-11-21T00:00:00Z          6         20
# 8       12     God  2016-11-21T00:00:00Z          7         20
# 9       13     God  2016-11-21T00:00:00Z          6          8
# 10      14     God  2016-11-21T00:00:00Z         10         20
# 11      15     God  2016-11-21T00:00:00Z          5         30
# 12      16     God  2016-11-24T00:00:00Z          6         47
# 13      17     God  2016-11-21T00:00:00Z          8         20
# ...

# %%
print(SAFI_God.shape)
print(SAFI_Ruaca.shape)
# Out:
# (43, 4)
# (49, 4)

# %%
SAFI_allRows = SAFI_allRows.reset_index(drop = True)
SAFI_allRows
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 0        1     God  2016-11-17T00:00:00Z          3          4
# 1        1     God  2016-11-17T00:00:00Z          7          9
# 2        3     God  2016-11-17T00:00:00Z         10         15
# 3        4     God  2016-11-17T00:00:00Z          7          6
# 4        5     God  2016-11-17T00:00:00Z          7         40
# 5        6     God  2016-11-17T00:00:00Z          3          3
# 6        7     God  2016-11-17T00:00:00Z          6         38
# 7       11     God  2016-11-21T00:00:00Z          6         20
# 8       12     God  2016-11-21T00:00:00Z          7         20
# 9       13     God  2016-11-21T00:00:00Z          6          8
# 10      14     God  2016-11-21T00:00:00Z         10         20
# 11      15     God  2016-11-21T00:00:00Z          5         30
# 12      16     God  2016-11-24T00:00:00Z          6         47
# 13      17     God  2016-11-21T00:00:00Z          8         20
# ...

# %%
SAFI_God = pd.read_csv('../data/SAFI_God.csv', usecols=range(0,4))
print(SAFI_God.columns)
SAFI_Ruaca = pd.read_csv('../data/SAFI_Ruaca.csv', usecols=range(1,5))
print(SAFI_Ruaca.columns)
SAFI_allRows = pd.concat([SAFI_God, SAFI_Ruaca])
SAFI_allRows
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_membrs'], dtype='object')
# Index(['village', 'interview_date', 'no_membrs', 'years_liv'], dtype='object')
# /Users/Katrin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """
#           interview_date  key_ID  no_membrs village  years_liv
# 0   2016-11-17T00:00:00Z     1.0          3     God        NaN
# 1   2016-11-17T00:00:00Z     1.0          7     God        NaN
# 2   2016-11-17T00:00:00Z     3.0         10     God        NaN
# 3   2016-11-17T00:00:00Z     4.0          7     God        NaN
# 4   2016-11-17T00:00:00Z     5.0          7     God        NaN
# 5   2016-11-17T00:00:00Z     6.0          3     God        NaN
# ...

# %% [markdown]
# ## Scenario 2 - Adding the columns from one Dataframe to those of another Dataframe

# %%
SAFI_num = pd.read_csv('../data/SAFI_numCols.csv')
print(SAFI_num.columns)
print(SAFI_num.shape)
# Out:
# Index(['instanceID', 'no_membrs', 'years_liv', 'rooms'], dtype='object')
# (131, 4)

# %%
SAFI_char = pd.read_csv('../data/SAFI_charCols.csv')
print(SAFI_char.columns)
print(SAFI_char.shape)
# Out:
# Index(['instanceID', 'village', 'respondent_wall_type', 'items_owned'], dtype='object')
# (131, 4)

# %%
SAFI_allCols = pd.concat([SAFI_num, SAFI_char], axis = 1)
SAFI_allCols
# Out:
#                                     instanceID  no_membrs  years_liv  rooms  \
# 0    uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1    uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
# 2    uuid:193d7daf-9582-409b-bf09-027dd36f9007         10         15      1
# 3    uuid:148d1105-778a-4755-aa71-281eadd4a973          7          6      1
# 4    uuid:2c867811-9696-4966-9866-f35c3e97d02d          7         40      1
# 5    uuid:daa56c91-c8e3-44c3-a663-af6a49a2ca70          3          3      1
# 6    uuid:ae20a58d-56f4-43d7-bafa-e7963d850844          6         38      1
# 7    uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a         12         70      3
# 8    uuid:846103d2-b1db-4055-b502-9cd510bb7b37          8          6      1
# 9    uuid:8f4e49bc-da81-4356-ae34-e0d794a23721         12         23      5
# 10   uuid:d29b44e3-3348-4afc-aa4d-9eb34c89d483          6         20      1
# ...

# %% [markdown]
# ## Scenario 3 - Using merge to join columns

# %%
SAFI_join = pd.merge(SAFI_num, SAFI_char, how = 'inner')
SAFI_join
# Out:
#                                     instanceID  no_membrs  years_liv  rooms  \
# 0    uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1    uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
# 2    uuid:193d7daf-9582-409b-bf09-027dd36f9007         10         15      1
# 3    uuid:148d1105-778a-4755-aa71-281eadd4a973          7          6      1
# 4    uuid:2c867811-9696-4966-9866-f35c3e97d02d          7         40      1
# 5    uuid:daa56c91-c8e3-44c3-a663-af6a49a2ca70          3          3      1
# 6    uuid:ae20a58d-56f4-43d7-bafa-e7963d850844          6         38      1
# 7    uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a         12         70      3
# 8    uuid:846103d2-b1db-4055-b502-9cd510bb7b37          8          6      1
# 9    uuid:8f4e49bc-da81-4356-ae34-e0d794a23721         12         23      5
# 10   uuid:d29b44e3-3348-4afc-aa4d-9eb34c89d483          6         20      1
# ...

# %%
SAFI_join = pd.merge(SAFI_num, SAFI_char, how = 'inner', on = 'instanceID')

# %%
SAFI_join
# Out:
#                                     instanceID  no_membrs  years_liv  rooms  \
# 0    uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1    uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
# 2    uuid:193d7daf-9582-409b-bf09-027dd36f9007         10         15      1
# 3    uuid:148d1105-778a-4755-aa71-281eadd4a973          7          6      1
# 4    uuid:2c867811-9696-4966-9866-f35c3e97d02d          7         40      1
# 5    uuid:daa56c91-c8e3-44c3-a663-af6a49a2ca70          3          3      1
# 6    uuid:ae20a58d-56f4-43d7-bafa-e7963d850844          6         38      1
# 7    uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a         12         70      3
# 8    uuid:846103d2-b1db-4055-b502-9cd510bb7b37          8          6      1
# 9    uuid:8f4e49bc-da81-4356-ae34-e0d794a23721         12         23      5
# 10   uuid:d29b44e3-3348-4afc-aa4d-9eb34c89d483          6         20      1
# ...

# %%
SAFI_join = pd.merge(SAFI_num, SAFI_char, how = 'inner', left_on = 'instanceID', right_on = 'instanceID')
SAFI_join
# Out:
#                                     instanceID  no_membrs  years_liv  rooms  \
# 0    uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1    uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
# 2    uuid:193d7daf-9582-409b-bf09-027dd36f9007         10         15      1
# 3    uuid:148d1105-778a-4755-aa71-281eadd4a973          7          6      1
# 4    uuid:2c867811-9696-4966-9866-f35c3e97d02d          7         40      1
# 5    uuid:daa56c91-c8e3-44c3-a663-af6a49a2ca70          3          3      1
# 6    uuid:ae20a58d-56f4-43d7-bafa-e7963d850844          6         38      1
# 7    uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a         12         70      3
# 8    uuid:846103d2-b1db-4055-b502-9cd510bb7b37          8          6      1
# 9    uuid:8f4e49bc-da81-4356-ae34-e0d794a23721         12         23      5
# 10   uuid:d29b44e3-3348-4afc-aa4d-9eb34c89d483          6         20      1
# ...

# %% [markdown]
# ## Exercise 11-01 join

# %%
# %load ../code/join.py
1. Load `SAFI_God.csv` and `SAFI_Ruaca.csv` into Dataframes and explore their contents to determine how they should be joined.
2. Using the `SAFI_God` and `SAFI_Ruaca` csv files, create a Dataframe which is the result of an outer join using the `key_ID` column to join on.
3. What do you notice about the column names in the new Dataframe?
4. Using `shift`+`tab` in Jupyter examine the possible parameters for the `merge()` function.
5. Re-write the code so that the columns names which are common to both files have suffixes indicating the filename from which they come.
6. If you add the parameter `indicator=True`, what additional information is provided in the resulting Dataframe?

# %%
# 1.
SAFI_God = pd.read_csv('../data/SAFI_God.csv')
SAFI_Ruaca = pd.read_csv('../data/SAFI_Ruaca.csv')
print(SAFI_God.shape)
print(SAFI_God.columns)
print(SAFI_Ruaca.shape)
print(SAFI_Ruaca.columns)
# Out:
# (43, 14)
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')
# (49, 14)
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')

# %%
# 2.
SAFI_join = pd.merge(SAFI_God, SAFI_Ruaca, how='outer', on = 'key_ID')
SAFI_join
# Out:
#     key_ID village_x      interview_date_x  no_membrs_x  years_liv_x  \
# 0        1       God  2016-11-17T00:00:00Z          3.0          4.0
# 1        1       God  2016-11-17T00:00:00Z          7.0          9.0
# 2        3       God  2016-11-17T00:00:00Z         10.0         15.0
# 3        4       God  2016-11-17T00:00:00Z          7.0          6.0
# 4        5       God  2016-11-17T00:00:00Z          7.0         40.0
# 5        6       God  2016-11-17T00:00:00Z          3.0          3.0
# 6        7       God  2016-11-17T00:00:00Z          6.0         38.0
# 7       11       God  2016-11-21T00:00:00Z          6.0         20.0
# 8       12       God  2016-11-21T00:00:00Z          7.0         20.0
# 9       13       God  2016-11-21T00:00:00Z          6.0          8.0
# 10      14       God  2016-11-21T00:00:00Z         10.0         20.0
# 11      15       God  2016-11-21T00:00:00Z          5.0         30.0
# 12      16       God  2016-11-24T00:00:00Z          6.0         47.0
# ...

# %%
# 4.
SAFI_join = pd.merge(SAFI_God, SAFI_Ruaca, how='outer', on = 
'key_ID',suffixes=('_God', '_Ruaca'))
SAFI_join
# Out:
#     key_ID village_God    interview_date_God  no_membrs_God  years_liv_God  \
# 0        1         God  2016-11-17T00:00:00Z            3.0            4.0
# 1        1         God  2016-11-17T00:00:00Z            7.0            9.0
# 2        3         God  2016-11-17T00:00:00Z           10.0           15.0
# 3        4         God  2016-11-17T00:00:00Z            7.0            6.0
# 4        5         God  2016-11-17T00:00:00Z            7.0           40.0
# 5        6         God  2016-11-17T00:00:00Z            3.0            3.0
# 6        7         God  2016-11-17T00:00:00Z            6.0           38.0
# 7       11         God  2016-11-21T00:00:00Z            6.0           20.0
# 8       12         God  2016-11-21T00:00:00Z            7.0           20.0
# 9       13         God  2016-11-21T00:00:00Z            6.0            8.0
# 10      14         God  2016-11-21T00:00:00Z           10.0           20.0
# ...

# %%
# 6.
SAFI_join = pd.merge(SAFI_God, SAFI_Ruaca, how='outer', on = 
'key_ID',suffixes=('_God', '_Ruaca'), indicator = True)
SAFI_join
# Out:
#     key_ID village_God    interview_date_God  no_membrs_God  years_liv_God  \
# 0        1         God  2016-11-17T00:00:00Z            3.0            4.0
# 1        1         God  2016-11-17T00:00:00Z            7.0            9.0
# 2        3         God  2016-11-17T00:00:00Z           10.0           15.0
# 3        4         God  2016-11-17T00:00:00Z            7.0            6.0
# 4        5         God  2016-11-17T00:00:00Z            7.0           40.0
# 5        6         God  2016-11-17T00:00:00Z            3.0            3.0
# 6        7         God  2016-11-17T00:00:00Z            6.0           38.0
# 7       11         God  2016-11-21T00:00:00Z            6.0           20.0
# 8       12         God  2016-11-21T00:00:00Z            7.0           20.0
# 9       13         God  2016-11-21T00:00:00Z            6.0            8.0
# 10      14         God  2016-11-21T00:00:00Z           10.0           20.0
# ...
