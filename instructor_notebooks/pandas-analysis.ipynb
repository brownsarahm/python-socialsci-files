# %%
import pandas as pd

# %%
df = pd.read_csv("data/SAFI_results.csv")

# %%
df
# Out:
#      Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0          0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1          1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2          2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3          3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4          4         17/11/2016             5  2017-04-02T15:10:35.000Z
# 5          5         17/11/2016             6  2017-04-02T15:27:25.000Z
# 6          6         17/11/2016             7  2017-04-02T15:38:01.000Z
# 7          7         16/11/2016             8  2017-04-02T15:59:52.000Z
# 8          8         16/11/2016             9  2017-04-02T16:23:36.000Z
# 9          9         16/12/2016            10  2017-04-02T17:03:28.000Z
# 10        10         21/11/2016            11  2017-04-03T03:16:15.000Z
# 11        11         21/11/2016            12  2017-04-03T03:31:13.000Z
# ...

# %%
df.describe()
# Out:
#           Column1  A03_quest_no  A11_years_farm  B16_years_liv  B_no_membrs  \
# count  131.000000    131.000000      131.000000     131.000000    131.00000
# mean    65.000000     85.473282       15.832061      23.053435      7.19084
# std     37.960506     63.151628       10.903883      16.913041      3.17227
# min      0.000000      1.000000        1.000000       1.000000      2.00000
# 25%     32.500000     32.500000        8.000000      12.000000      5.00000
# 50%     65.000000     66.000000       15.000000      20.000000      7.00000
# 75%     97.500000    138.000000       20.500000      27.500000      9.00000
# max    130.000000    202.000000       60.000000      96.000000     19.00000
#
#        C02_respondent_wall_type_other  C05_buildings_in_compound   C06_rooms  \
# count                             0.0                 131.000000  131.000000
# mean                              NaN                   2.068702    1.740458
# ...

# %%
df["B_no_membrs"].describe()
# Out:
# count    131.00000
# mean       7.19084
# std        3.17227
# min        2.00000
# 25%        5.00000
# 50%        7.00000
# 75%        9.00000
# max       19.00000
# Name: B_no_membrs, dtype: float64

# %%
df.B_no_membrs.describe()
# Out:
# count    131.00000
# mean       7.19084
# std        3.17227
# min        2.00000
# 25%        5.00000
# 50%        7.00000
# 75%        9.00000
# max       19.00000
# Name: B_no_membrs, dtype: float64

# %%
df.B_no_membrs.min()
# Out:
# 2

# %%
df.B_no_membrs.std()
# Out:
# 3.1722704895263734

# %%
df.B_no_membrs.sum()
# Out:
# 942

# %%
df.B_no_membrs.mean()
# Out:
# 7.190839694656488

# %% [markdown]
# # %load code/counts
# Compare the count values returned for the `B_no_membrs` and the `E19_period_use` variables.
#
# 1. How can you investigate why they're different?
# 2. How does this affect the calculation of the mean values?

# %%
df.B_no_membrs.count()
# Out:
# 131

# %%
df.E19_period_use.count()
# Out:
# 92

# %%
df[ ["B_no_membrs", "E19_period_use"] ].count()
# Out:
# B_no_membrs       131
# E19_period_use     92
# dtype: int64

# %%
df[ ["B_no_membrs", "E19_period_use"] ]
# Out:
#      B_no_membrs  E19_period_use
# 0              3             NaN
# 1              7             2.0
# 2             10             NaN
# 3              7             NaN
# 4              7             NaN
# 5              3             NaN
# 6              6            10.0
# 7             12            10.0
# 8              8             6.0
# 9             12            22.0
# 10             6             NaN
# 11             7            20.0
# 12             6             7.0
# 13            10             NaN
# 14             5            30.0
# 15             6             NaN
# 16             8             NaN
# 17             4             NaN
# 18             9             NaN
# 19             6             NaN
# 20             8            20.0
# 21             4             NaN
# 22            10             NaN
# 23             6             8.0
# 24            11            10.0
# 25             3             2.0
# 26             7             NaN
# ...

# %%
df[ ["B_no_membrs", "E19_period_use"] ].mean()
# Out:
# B_no_membrs        7.190840
# E19_period_use    12.043478
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Column1                             0
# A01_interview_date                  0
# A03_quest_no                        0
# A04_start                           0
# A05_end                             0
# A06_province                        0
# A07_district                        0
# A08_ward                            0
# A09_village                         0
# A11_years_farm                      0
# A12_agr_assoc                       0
# B11_remittance_money                0
# B16_years_liv                       0
# B17_parents_liv                     0
# B18_sp_parents_liv                  0
# B19_grand_liv                       0
# B20_sp_grand_liv                    0
# B_no_membrs                         0
# C01_respondent_roof_type            0
# C02_respondent_wall_type            0
# C02_respondent_wall_type_other    131
# C03_respondent_floor_type           0
# C04_window_type                     0
# C05_buildings_in_compound           0
# C06_rooms                           0
# ...

# %%
df.E19_period_use.isnull().sum()
# Out:
# 39

# %%
df.shape
# Out:
# (131, 55)

# %%
import numpy as np

np.NaN
# Out:
# nan

# %%
df.E19_period_use.replace(0, np.NaN, inplace=True)

# %%
df.E19_period_use
# Out:
# 0       NaN
# 1       2.0
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6      10.0
# 7      10.0
# 8       6.0
# 9      22.0
# 10      NaN
# 11     20.0
# 12      7.0
# 13      NaN
# 14     30.0
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20     20.0
# 21      NaN
# 22      NaN
# 23      8.0
# 24     10.0
# 25      2.0
# 26      NaN
# 27      2.0
# 28      4.0
# 29      NaN
#        ...
# 101     1.0
# 102    21.0
# 103     NaN
# 104    22.0
# 105     2.0
# 106     NaN
# 107     3.0
# 108     3.0
# 109     NaN
# 110    16.0
# 111     NaN
# 112     NaN
# 113     5.0
# 114    12.0
# 115     8.0
# 116     2.0
# 117     3.0
# 118    10.0
# 119     2.0
# 120    16.0
# 121    13.0
# 122    11.0
# 123     7.0
# 124     3.0
# 125     5.0
# 126     4.0
# 127    10.0
# 128     2.0
# 129     6.0
# 130     NaN
# Name: E19_period_use, Length: 131, dtype: float64

# %%
pd.unique(df.C01_respondent_roof_type)
# Out:
# array(['grass', 'mabatisloping', 'mabatipitched'], dtype=object)

# %%
df.C01_respondent_roof_type
# Out:
# 0              grass
# 1              grass
# 2      mabatisloping
# 3      mabatisloping
# 4              grass
# 5              grass
# 6              grass
# 7      mabatisloping
# 8              grass
# 9      mabatisloping
# 10             grass
# 11     mabatisloping
# 12             grass
# 13             grass
# 14             grass
# 15             grass
# 16             grass
# 17             grass
# 18     mabatisloping
# 19             grass
# 20     mabatisloping
# 21             grass
# 22     mabatisloping
# 23     mabatisloping
# 24     mabatisloping
# 25     mabatisloping
# 26             grass
# 27             grass
# 28     mabatisloping
# 29             grass
#            ...
# 101    mabatisloping
# 102    mabatisloping
# 103            grass
# 104    mabatisloping
# 105    mabatisloping
# 106            grass
# 107    mabatisloping
# 108            grass
# 109    mabatisloping
# 110    mabatisloping
# 111            grass
# 112            grass
# ...

# %%
grouped_data = df.groupby('C01_respondent_roof_type')

# %%
grouped_data.describe()
# Out:
#                          A03_quest_no                                     \
#                                 count       mean        std   min    25%
# C01_respondent_roof_type
# grass                            73.0  82.342466  63.100497   1.0  31.00
# mabatipitched                    10.0  90.000000  50.042204  32.0  67.25
# mabatisloping                    48.0  89.291667  66.463543   3.0  28.25
#
#                                               A11_years_farm             \
#                            50%     75%    max          count       mean
# C01_respondent_roof_type
# grass                     60.0  143.00  201.0           73.0  14.986301
# mabatipitched             73.0   79.50  182.0           10.0  21.300000
# mabatisloping             78.0  135.75  202.0           48.0  15.979167
#
#                             ...     gps:Latitude            gps:Longitude  \
#                             ...              75%        max         count
# C01_respondent_roof_type    ...
# ...

# %%
grouped_data.A03_quest_no.describe()
# Out:
#                           count       mean        std   min    25%   50%  \
# C01_respondent_roof_type
# grass                      73.0  82.342466  63.100497   1.0  31.00  60.0
# mabatipitched              10.0  90.000000  50.042204  32.0  67.25  73.0
# mabatisloping              48.0  89.291667  66.463543   3.0  28.25  78.0
#
#                              75%    max
# C01_respondent_roof_type
# grass                     143.00  201.0
# mabatipitched              79.50  182.0
# mabatisloping             135.75  202.0

# %%
grouped_data.A03_quest_no.mean()
# Out:
# C01_respondent_roof_type
# grass            82.342466
# mabatipitched    90.000000
# mabatisloping    89.291667
# Name: A03_quest_no, dtype: float64

# %%
grouped_data.A03_quest_no.std()
# Out:
# C01_respondent_roof_type
# grass            63.100497
# mabatipitched    50.042204
# mabatisloping    66.463543
# Name: A03_quest_no, dtype: float64

# %%
grouped_data = df.groupby( ['C01_respondent_roof_type','C02_respondent_wall_type'] )

# %%
grouped_data.A11_years_farm.describe()
# Out:
#                                                    count       mean  \
# C01_respondent_roof_type C02_respondent_wall_type
# grass                    burntbricks                22.0  16.772727
#                          muddaub                    42.0  13.904762
#                          sunbricks                   9.0  15.666667
# mabatipitched            burntbricks                 6.0  18.000000
#                          muddaub                     3.0  28.333333
#                          sunbricks                   1.0  20.000000
# mabatisloping            burntbricks                39.0  14.666667
#                          cement                      1.0  10.000000
#                          muddaub                     1.0  22.000000
#                          sunbricks                   7.0  23.285714
#
#                                                          std   min    25%  \
# C01_respondent_roof_type C02_respondent_wall_type
# ...

# %% [markdown]
# # %load code/groupby
# 1. Read in the SAFI_results.csv dataset.
# 2. Get a list of the different 'C01_respondent_roof_type' values.
# 3. Groupby 'C01_respondent_roof_type' and describe the results.
# 4. Remove rows with NULL values for 'E_no_group_count'.
# 5. repeat steps 2 & 3 and compare the results.

# %%
df.dropna(subset=["E_no_group_count"]).mean()
# Out:
# Column1                            46.871795
# A03_quest_no                       58.717949
# A11_years_farm                     16.435897
# B16_years_liv                      20.128205
# B_no_membrs                         5.769231
# C02_respondent_wall_type_other           NaN
# C05_buildings_in_compound           1.717949
# C06_rooms                           1.692308
# D_plots_count                       1.589744
# E17_no_enough_water                      NaN
# E19_period_use                           NaN
# E20_exper_other                          NaN
# E21_other_meth                           NaN
# E23_memb_assoc                           NaN
# E24_resp_assoc                           NaN
# E25_fees_water                           NaN
# E26_affect_conflicts                     NaN
# E_no_group_count                    1.589744
# E_yes_group_count                        NaN
# F04_need_money                           NaN
# F05_money_source_other                   NaN
# ...

# %%
df.mean()
# Out:
# Column1                            65.000000
# A03_quest_no                       85.473282
# A11_years_farm                     15.832061
# B16_years_liv                      23.053435
# B_no_membrs                         7.190840
# C02_respondent_wall_type_other           NaN
# C05_buildings_in_compound           2.068702
# C06_rooms                           1.740458
# D_plots_count                       2.229008
# E19_period_use                     12.043478
# E_no_group_count                    1.589744
# E_yes_group_count                   2.500000
# F05_money_source_other                   NaN
# F10_liv_owned_other                      NaN
# F_liv_count                         2.366412
# G01_no_meals                        2.603053
# _members_count                      7.190840
# _note                                    NaN
# gps:Accuracy                       71.115344
# gps:Altitude                      648.221374
# gps:Latitude                      -19.102671
# ...

# %%
df[df['E_no_group_count'].notnull()]
# Out:
#      Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0          0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 2          2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3          3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4          4         17/11/2016             5  2017-04-02T15:10:35.000Z
# 5          5         17/11/2016             6  2017-04-02T15:27:25.000Z
# 10        10         21/11/2016            11  2017-04-03T03:16:15.000Z
# 13        13         21/11/2016            14  2017-04-03T04:19:57.000Z
# 15        15         24/11/2016            16  2017-04-03T05:29:24.000Z
# 16        16         21/11/2016            17  2017-04-03T05:41:42.000Z
# 17        17         21/11/2016            18  2017-04-03T12:27:04.000Z
# 18        18         21/11/2016            19  2017-04-03T12:40:14.000Z
# 19        19         21/11/2016            20  2017-04-03T14:04:50.000Z
# ...

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. deprecated:: 0.23.0: Pass tuple or list to drop on multiple
#         axes.
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
#         * 'any' : If any NA values are present, drop that row or column.
# ...

# %%
import pandas as pd

# %%
df_a = pd.read_csv("data/SN7577i_a.csv")
df_b = pd.read_csv("data/SN7577i_b.csv")

# %%
df_a
# Out:
#    Id  Q1  Q2  Q3  Q4
# 0   1   1  -1   1   8
# 1   2   3  -1   1   4
# 2   3  10   3   2   6
# 3   4   9  -1  10  10
# 4   5  10   2   6   1
# 5   6   1  -1   1   1
# 6   7   1  -1   1   8
# 7   8   1  -1   1   1
# 8   9   9  -1  10  10
# 9  10   2  -1   1   1

# %%
df_b
# Out:
#      Id  Q1  Q2  Q3  Q4
# 0  1277  10  10   4   6
# 1  1278   2  -1   5   4
# 2  1279   2  -1   4   5
# 3  1280   1  -1   2   3
# 4  1281  10   2   3   4
# 5  1282   2  -1   3   6
# 6  1283  10  10   2  10
# 7  1284   9  -1   8   9
# 8  1285  11  11   1   2
# 9  1286  10   6   6   6

# %%
df_all = pd.concat( [df_a, df_b] )

# %%
df_all
# Out:
#      Id  Q1  Q2  Q3  Q4
# 0     1   1  -1   1   8
# 1     2   3  -1   1   4
# 2     3  10   3   2   6
# 3     4   9  -1  10  10
# 4     5  10   2   6   1
# 5     6   1  -1   1   1
# 6     7   1  -1   1   8
# 7     8   1  -1   1   1
# 8     9   9  -1  10  10
# 9    10   2  -1   1   1
# 0  1277  10  10   4   6
# 1  1278   2  -1   5   4
# 2  1279   2  -1   4   5
# 3  1280   1  -1   2   3
# 4  1281  10   2   3   4
# 5  1282   2  -1   3   6
# 6  1283  10  10   2  10
# 7  1284   9  -1   8   9
# 8  1285  11  11   1   2
# 9  1286  10   6   6   6

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#       Id  Q1  Q2  Q3  Q4
# 0      1   1  -1   1   8
# 1      2   3  -1   1   4
# 2      3  10   3   2   6
# 3      4   9  -1  10  10
# 4      5  10   2   6   1
# 5      6   1  -1   1   1
# 6      7   1  -1   1   8
# 7      8   1  -1   1   1
# 8      9   9  -1  10  10
# 9     10   2  -1   1   1
# 10  1277  10  10   4   6
# 11  1278   2  -1   5   4
# 12  1279   2  -1   4   5
# 13  1280   1  -1   2   3
# 14  1281  10   2   3   4
# 15  1282   2  -1   3   6
# 16  1283  10  10   2  10
# 17  1284   9  -1   8   9
# 18  1285  11  11   1   2
# 19  1286  10   6   6   6

# %%
df_c = pd.read_csv("data/SN7577i_c.csv")
df_d = pd.read_csv("data/SN7577i_d.csv")

# %%
df_combined = pd.concat( [df_c, df_d] , axis = 1)

# %%
df_combined
# Out:
#    Id  maritl  numhhd  Id  Q1  Q2
# 0   1       6       3   1   1  -1
# 1   2       4       3   2   3  -1
# 2   3       6       2   3  10   3
# 3   4       4       1   4   9  -1
# 4   5       4       1   5  10   2
# 5   6       2       2   6   1  -1
# 6   7       2       2   7   1  -1
# 7   8       2       2   8   1  -1
# 8   9       6       2   9   9  -1
# 9  10       6       1  10   2  -1

# %%
df_cd = pd.merge(df_c, df_d, how="inner", on = "Id")

# %%
df_cd
# Out:
#    Id  maritl  numhhd  Q1  Q2
# 0   1       6       3   1  -1
# 1   2       4       3   3  -1
# 2   3       6       2  10   3
# 3   4       4       1   9  -1
# 4   5       4       1  10   2
# 5   6       2       2   1  -1
# 6   7       2       2   1  -1
# 7   8       2       2   1  -1
# 8   9       6       2   9  -1
# 9  10       6       1   2  -1

# %% [markdown]
# # %load code/join
# 1. Load `SN7577i_aa.csv` and `SN7577i_bb.csv` into dataframes and explore their contents to determine how they should be joined.
# 2. Using the `SN7577i_aa` and `SN7577i_bb` csv files, create a dataframe which is the result of an outer join using the 'Id' column to join on.
# 3. What do you notice about the column names in the new dataframe?
# 4. Using shift+ tab in Jupyter examine the possible parameters for the `merge` method.
# 5. re-write the code so that the columns names which are common to both files have suffixes indicating the filename from which they come
# 6. If you add the parameter 'indicator=True', what additional information is provided in the resulting dataframe?

# %%
df_aa = pd.read_csv("data/SN7577i_aa.csv")
df_bb = pd.read_csv("data/SN7577i_bb.csv")

# %%
df_aa
# Out:
#    Id  Q1  Q2  Q3
# 0   1   1  -1   1
# 1   2   3  -1   1
# 2   3  10   3   2
# 3   4   9  -1  10
# 4   5  10   2   6
# 5   6   1  -1   1
# 6   7   1  -1   1
# 7   8   1  -1   1
# 8   9   9  -1  10
# 9  10   2  -1   1

# %%
df_bb
# Out:
#      Id  Q1  Q2  Q4
# 0  1277  10  10   6
# 1  1278   2  -1   4
# 2  1279   2  -1   5
# 3  1280   1  -1   3
# 4  1281  10   2   4
# 5  1282   2  -1   6
# 6  1283  10  10  10
# 7  1284   9  -1   9
# 8  1285  11  11   2
# 9  1286  10   6   6

# %%
df_aabb = pd.merge(df_aa,df_bb, how='outer', on='Id', suffixes=("_aa", "_bb"))

# %%
df_aabb
# Out:
#       Id  Q1_aa  Q2_aa    Q3  Q1_bb  Q2_bb    Q4
# 0      1    1.0   -1.0   1.0    NaN    NaN   NaN
# 1      2    3.0   -1.0   1.0    NaN    NaN   NaN
# 2      3   10.0    3.0   2.0    NaN    NaN   NaN
# 3      4    9.0   -1.0  10.0    NaN    NaN   NaN
# 4      5   10.0    2.0   6.0    NaN    NaN   NaN
# 5      6    1.0   -1.0   1.0    NaN    NaN   NaN
# 6      7    1.0   -1.0   1.0    NaN    NaN   NaN
# 7      8    1.0   -1.0   1.0    NaN    NaN   NaN
# 8      9    9.0   -1.0  10.0    NaN    NaN   NaN
# 9     10    2.0   -1.0   1.0    NaN    NaN   NaN
# 10  1277    NaN    NaN   NaN   10.0   10.0   6.0
# 11  1278    NaN    NaN   NaN    2.0   -1.0   4.0
# 12  1279    NaN    NaN   NaN    2.0   -1.0   5.0
# 13  1280    NaN    NaN   NaN    1.0   -1.0   3.0
# 14  1281    NaN    NaN   NaN   10.0    2.0   4.0
# 15  1282    NaN    NaN   NaN    2.0   -1.0   6.0
# 16  1283    NaN    NaN   NaN   10.0   10.0  10.0
# 17  1284    NaN    NaN   NaN    9.0   -1.0   9.0
# ...
