# %% [markdown]
# # Libraries

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import pandas as pd

# %%
pd.read_csv('data/SAFI_clean.csv')
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %%
safi_df = pd.read_csv('data/SAFI_clean.csv')

# %%
type(safi_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# %load code/csv-sep

# %% [markdown]
# What happens if you specify the tab character as column separator with `sep='\t'` when you load the data?

# %%
pd.read_csv('data/SAFI_clean.csv',sep='\t')
# Out:
#     key_ID,village,interview_date,no_membrs,years_liv,respondent_wall_type,rooms,memb_assoc,affect_conflicts,liv_count,items_owned,no_meals,months_lack_food,instanceID
# 0    1,God,2016-11-17T00:00:00Z,3,4,muddaub,1,NULL,...
# 1    1,God,2016-11-17T00:00:00Z,7,9, muddaub,1,yes,...
# 2    3,God,2016-11-17T00:00:00Z,10,15, burntbricks,...
# 3    4,God,2016-11-17T00:00:00Z,7,6, burntbricks,1,...
# 4    5,God,2016-11-17T00:00:00Z,7,40,burntbricks,1,...
# 5    6,God,2016-11-17T00:00:00Z,3,3,muddaub,1,NULL,...
# 6    7,God,2016-11-17T00:00:00Z,6,38,muddaub,1,no,n...
# 7    8,Chirodzo,2016-11-16T00:00:00Z,12,70,burntbri...
# 8    9,Chirodzo,2016-11-16T00:00:00Z,8,6,burntbrick...
# 9    10,Chirodzo,2016-12-16T00:00:00Z,12,23,burntbr...
# 10   11,God,2016-11-21T00:00:00Z,6,20,sunbricks,1,N...
# 11   12,God,2016-11-21T00:00:00Z,7,20,burntbricks,3...
# 12   13,God,2016-11-21T00:00:00Z,6,8,burntbricks,1,...
# 13   14,God,2016-11-21T00:00:00Z,10,20,burntbricks,...
# ...

# %%
safi_df.head()
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0       1     God  2016-11-17T00:00:00Z          3          4
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
# 4       5     God  2016-11-17T00:00:00Z          7         40
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0              muddaub      1        NaN              NaN          1
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
# 4          burntbricks      1        NaN              NaN          4
#
#                                          items_owned  no_meals  \
# 0               bicycle;television;solar_panel;table         2
# ...

# %%
safi_df.tail(2)
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 129     199  Chirodzo  2017-06-04T00:00:00Z          7         17
# 130     200  Chirodzo  2017-06-04T00:00:00Z          8         20
#
#     respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 129          burntbricks      2        yes        more_once          2
# 130          burntbricks      2        NaN              NaN          3
#
#                                            items_owned  no_meals  \
# 129  cow_cart;lorry;motorcyle;computer;television;r...         3
# 130  radio;cow_plough;solar_panel;solar_torch;table...         3
#
#     months_lack_food                                 instanceID
# 129          Nov;Dec  uuid:ffc83162-ff24-4a87-8709-eff17abc0b3b
# 130          Oct;Nov  uuid:aa77a0d7-7142-41c8-b494-483a5b68d8a7

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
safi_df = pd.read_csv('data/SAFI_clean.csv',index_col='instanceID')
safi_df.index
# Out:
# Index(['uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef',
#        'uuid:099de9c9-3e5e-427b-8452-26250e840d6e',
#        'uuid:193d7daf-9582-409b-bf09-027dd36f9007',
#        'uuid:148d1105-778a-4755-aa71-281eadd4a973',
#        'uuid:2c867811-9696-4966-9866-f35c3e97d02d',
#        'uuid:daa56c91-c8e3-44c3-a663-af6a49a2ca70',
#        'uuid:ae20a58d-56f4-43d7-bafa-e7963d850844',
#        'uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a',
#        'uuid:846103d2-b1db-4055-b502-9cd510bb7b37',
#        'uuid:8f4e49bc-da81-4356-ae34-e0d794a23721',
#        ...
#        'uuid:43ec6132-478c-4f87-878d-fb3c0c4d0c74',
#        'uuid:64fc743e-8176-40f6-8ae4-36ae97fac1d9',
#        'uuid:c17e374c-280b-4e78-bf21-74a7c1c73492',
#        'uuid:dad53aff-b520-4015-a9e3-f5fdf9168fe1',
#        'uuid:f94409a6-e461-4e4c-a6fb-0072d3d58b00',
#        'uuid:69caea81-a4e5-4e8d-83cd-9c18d8e8d965',
#        'uuid:5ccc2e5a-ea90-48b5-8542-69400d5334df',
#        'uuid:95c11a30-d44f-40c4-8ea8-ec34fca6bbbf',
# ...

# %%
safi_df.head()
# Out:
#                                            key_ID village  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef       1     God
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e       1     God
# uuid:193d7daf-9582-409b-bf09-027dd36f9007       3     God
# uuid:148d1105-778a-4755-aa71-281eadd4a973       4     God
# uuid:2c867811-9696-4966-9866-f35c3e97d02d       5     God
#
#                                                  interview_date  no_membrs  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef  2016-11-17T00:00:00Z          3
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e  2016-11-17T00:00:00Z          7
# uuid:193d7daf-9582-409b-bf09-027dd36f9007  2016-11-17T00:00:00Z         10
# uuid:148d1105-778a-4755-aa71-281eadd4a973  2016-11-17T00:00:00Z          7
# uuid:2c867811-9696-4966-9866-f35c3e97d02d  2016-11-17T00:00:00Z          7
#
#                                            years_liv respondent_wall_type  \
# instanceID
# ...

# %%
len(safi_df)
# Out:
# 131

# %%
safi_df.shape
# Out:
# (131, 13)

# %%
safi_df.size
# Out:
# 1703

# %%
131*13
# Out:
# 1703

# %%
safi_df.dtypes
# Out:
# key_ID                   int64
# village                 object
# interview_date          object
# no_membrs                int64
# years_liv                int64
# respondent_wall_type    object
# rooms                    int64
# memb_assoc              object
# affect_conflicts        object
# liv_count                int64
# items_owned             object
# no_meals                 int64
# months_lack_food        object
# dtype: object

# %%
safi_df_some = pd.read_csv('data/SAFI_clean.csv',usecols=[0,1,2,11,12,13]
)

# %%
safi_df_some.shape
# Out:
# (131, 6)

# %%
safi_df['village'].head()
# Out:
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef    God
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e    God
# uuid:193d7daf-9582-409b-bf09-027dd36f9007    God
# uuid:148d1105-778a-4755-aa71-281eadd4a973    God
# uuid:2c867811-9696-4966-9866-f35c3e97d02d    God
# Name: village, dtype: object

# %%
safi_df.village.head()
# Out:
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef    God
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e    God
# uuid:193d7daf-9582-409b-bf09-027dd36f9007    God
# uuid:148d1105-778a-4755-aa71-281eadd4a973    God
# uuid:2c867811-9696-4966-9866-f35c3e97d02d    God
# Name: village, dtype: object

# %%
safi_df[1:4]
# Out:
#                                            key_ID village  \
# instanceID
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e       1     God
# uuid:193d7daf-9582-409b-bf09-027dd36f9007       3     God
# uuid:148d1105-778a-4755-aa71-281eadd4a973       4     God
#
#                                                  interview_date  no_membrs  \
# instanceID
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e  2016-11-17T00:00:00Z          7
# uuid:193d7daf-9582-409b-bf09-027dd36f9007  2016-11-17T00:00:00Z         10
# uuid:148d1105-778a-4755-aa71-281eadd4a973  2016-11-17T00:00:00Z          7
#
#                                            years_liv respondent_wall_type  \
# instanceID
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e          9              muddaub
# uuid:193d7daf-9582-409b-bf09-027dd36f9007         15          burntbricks
# uuid:148d1105-778a-4755-aa71-281eadd4a973          6          burntbricks
#
#                                            rooms memb_assoc affect_conflicts  \
# ...

# %%
# %load code/pdindex

# %% [markdown]
# See what happens when you try each of the following:
#
# 1. List the columns you want out of order from the way they appear in the file?
# 2. What happens if we put the same column name in twice?
# 3. What does python do if you use a non-existing column name? (a.k.a Typo)
# 4. Use help to figure out how to select a range of columns
# 5. How can you select only the first row?
# 6. What about the last 3 rows?

# %%
safi_df[['village','respondent_wall_type']].head(1)
# Out:
#                                           village respondent_wall_type
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef     God              muddaub

# %%
safi_df[['respondent_wall_type','village']].head(1)
# Out:
#                                           respondent_wall_type village
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef              muddaub     God

# %%
col_list = ['village','respondent_wall_type']
safi_df[col_list].head()
# Out:
#                                           village respondent_wall_type
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef     God              muddaub
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e     God              muddaub
# uuid:193d7daf-9582-409b-bf09-027dd36f9007     God          burntbricks
# uuid:148d1105-778a-4755-aa71-281eadd4a973     God          burntbricks
# uuid:2c867811-9696-4966-9866-f35c3e97d02d     God          burntbricks

# %%
safi_df[['village','village']].head(1)
# Out:
#                                           village village
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef     God     God

# %%
safi_df['villg']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'villg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-8bd7487cbd88> in <module>()
# ----> 1 safi_df['villg']
#
# ...

# %%
safi_df[:1]
# Out:
#                                            key_ID village  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef       1     God
#
#                                                  interview_date  no_membrs  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef  2016-11-17T00:00:00Z          3
#
#                                            years_liv respondent_wall_type  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          4              muddaub
#
#                                            rooms memb_assoc affect_conflicts  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef      1        NaN              NaN
#
#                                            liv_count  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          1
#
#                                                                     items_owned  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef  bicycle;television;solar_panel;table
#
# ...

# %%
ruaca_df = safi_df[(safi_df.village=='Ruaca')]
ruaca_df
# Out:
#                                            key_ID village  \
# instanceID
# uuid:58b37b6d-d6cd-4414-8790-b9c68bca98de      23   Ruaca
# uuid:661457d3-7e61-45e8-a238-7415e7548f82      24   Ruaca
# uuid:45ed84c4-114e-4df0-9f5d-c800806c2bee      25   Ruaca
# uuid:1c54ee24-22c4-4ee9-b1ad-42d483c08e2e      26   Ruaca
# uuid:3197cded-1fdc-4c0c-9b10-cfcc0bf49c4d      27   Ruaca
# uuid:1de53318-a8cf-4736-99b1-8239f8822473      28   Ruaca
# uuid:adcd7463-8943-4c67-b25f-f72311409476      29   Ruaca
# uuid:59341ead-92be-45a9-8545-6edf9f94fdc6      30   Ruaca
# uuid:cb06eb49-dd39-4150-8bbe-a599e074afe8      31   Ruaca
# uuid:25597af3-cd79-449c-a48a-fb9aea6c48bf      32   Ruaca
# uuid:0fbd2df1-2640-4550-9fbd-7317feaa4758      33   Ruaca
# uuid:761f9c49-ec93-4932-ba4c-cc7b78dfcef1      71   Ruaca
# uuid:429d279a-a519-4dcc-9f64-4673b0fd5d53     133   Ruaca
# uuid:59738c17-1cda-49ee-a563-acd76f6bc487     152   Ruaca
# uuid:7e7961ca-fa1c-4567-9bfa-a02f876e4e03     153   Ruaca
# ...

# %%
safi_df.iloc[range(0,10,3)]
# Out:
#                                            key_ID   village  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef       1       God
# uuid:148d1105-778a-4755-aa71-281eadd4a973       4       God
# uuid:ae20a58d-56f4-43d7-bafa-e7963d850844       7       God
# uuid:8f4e49bc-da81-4356-ae34-e0d794a23721      10  Chirodzo
#
#                                                  interview_date  no_membrs  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef  2016-11-17T00:00:00Z          3
# uuid:148d1105-778a-4755-aa71-281eadd4a973  2016-11-17T00:00:00Z          7
# uuid:ae20a58d-56f4-43d7-bafa-e7963d850844  2016-11-17T00:00:00Z          6
# uuid:8f4e49bc-da81-4356-ae34-e0d794a23721  2016-12-16T00:00:00Z         12
#
#                                            years_liv respondent_wall_type  \
# instanceID
# uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          4              muddaub
# uuid:148d1105-778a-4755-aa71-281eadd4a973          6          burntbricks
# ...

# %%
safi_df.sample(10)
# Out:
#                                            key_ID   village  \
# instanceID
# uuid:6570a7d0-6a0b-452c-aa2e-922500e35749      21       God
# uuid:3fe626b3-c794-48e1-a80f-5bfe440c507b     117     Ruaca
# uuid:e7c51ac4-24e4-475e-88e7-f85e896945e3     110     Ruaca
# uuid:e3a1dd8a-1bda-428c-a014-2b527f11ae64      42       God
# uuid:143f7478-0126-4fbc-86e0-5d324339206b      65  Chirodzo
# uuid:ece89122-ea99-4378-b67e-a170127ec4e6     180     Ruaca
# uuid:ff7496e7-984a-47d3-a8a1-13618b5683ce      35  Chirodzo
# uuid:f86933a5-12b8-4427-b821-43c5b039401d      69  Chirodzo
# uuid:e3554d22-35b1-4fb9-b386-dd5866ad5792      45  Chirodzo
# uuid:b4dff49f-ef27-40e5-a9d1-acf287b47358      43  Chirodzo
#
#                                                  interview_date  no_membrs  \
# instanceID
# uuid:6570a7d0-6a0b-452c-aa2e-922500e35749  2016-11-21T00:00:00Z          8
# uuid:3fe626b3-c794-48e1-a80f-5bfe440c507b  2017-05-11T00:00:00Z         10
# ...

# %%
safi_df.sample()

# %% [markdown]
# # Data Aggregation

# %%
safi_df.describe()
# Out:
#            key_ID  no_membrs   years_liv       rooms   liv_count    no_meals
# count  131.000000  131.00000  131.000000  131.000000  131.000000  131.000000
# mean    85.473282    7.19084   23.053435    1.740458    2.366412    2.603053
# std     63.151628    3.17227   16.913041    1.092547    1.082775    0.491143
# min      1.000000    2.00000    1.000000    1.000000    1.000000    2.000000
# 25%     32.500000    5.00000   12.000000    1.000000    1.000000    2.000000
# 50%     66.000000    7.00000   20.000000    1.000000    2.000000    3.000000
# 75%    138.000000    9.00000   27.500000    2.000000    3.000000    3.000000
# max    202.000000   19.00000   96.000000    8.000000    5.000000    3.000000

# %%
safi_df['village'].count()
# Out:
# 131

# %%
safi_df['no_membrs'].max()
# Out:
# 19

# %%
pd.unique(safi_df['village'])
# Out:
# array(['God', 'Chirodzo', 'Ruaca'], dtype=object)

# %%
# %load code/counts

# %% [markdown]
# 1. Get the unique entries for the `affect_conflicts` variable
# 2. Get the count value for `affect_conflicts` and compare it with the count for `respondent_wall_type`.
# 3. Why do you think they are different?

# %%
pd.unique(safi_df['affect_conflicts'])
# Out:
# array([nan, 'once', 'never', 'more_once', 'frequently'], dtype=object)

# %%
safi_df['affect_conflicts'].count()
# Out:
# 92

# %%
safi_df['respondent_wall_type'].count()
# Out:
# 131

# %%
safi_df['affect_conflicts'].isna().sum()
# Out:
# 39

# %%
safi_df.dropna().shape
# Out:
# (88, 13)

# %%
safi_df.dropna(inplace=True)
safi_df.shape
# Out:
# (88, 13)

# %%
safi_df.to_csv('data/SAFI_clean_nonan.csv')

# %%
safi_df_all = pd.read_csv('data/SAFI_clean.csv')
safi_df_all.affect_conflicts.head()
# Out:
# 0     NaN
# 1    once
# 2     NaN
# 3     NaN
# 4     NaN
# Name: affect_conflicts, dtype: object

# %%
import numpy as np
safi_df_all.affect_conflicts.replace(to_replace=np.NaN,
                                     value='no_response',
                                    inplace=True)

# %%
safi_df_all.affect_conflicts
# Out:
# 0             NaN
# 1            once
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6           never
# 7           never
# 8           never
# 9           never
# 10            NaN
# 11          never
# 12          never
# 13            NaN
# 14           once
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20          never
# 21            NaN
# 22            NaN
# 23          never
# 24          never
# 25          never
# 26            NaN
# 27      more_once
# 28     frequently
# 29            NaN
#           ...
# 101    frequently
# 102         never
# 103           NaN
# 104         never
# 105         never
# 106           NaN
# 107     more_once
# 108         never
# 109           NaN
# 110         never
# 111           NaN
# 112           NaN
# 113    frequently
# 114    frequently
# 115         never
# 116         never
# 117    frequently
# 118         never
# 119         never
# ...

# %%
safi_df_all.describe()
# Out:
#            key_ID  no_membrs   years_liv       rooms   liv_count    no_meals
# count  131.000000  131.00000  131.000000  131.000000  131.000000  131.000000
# mean    85.473282    7.19084   23.053435    1.740458    2.366412    2.603053
# std     63.151628    3.17227   16.913041    1.092547    1.082775    0.491143
# min      1.000000    2.00000    1.000000    1.000000    1.000000    2.000000
# 25%     32.500000    5.00000   12.000000    1.000000    1.000000    2.000000
# 50%     66.000000    7.00000   20.000000    1.000000    2.000000    3.000000
# 75%    138.000000    9.00000   27.500000    2.000000    3.000000    3.000000
# max    202.000000   19.00000   96.000000    8.000000    5.000000    3.000000

# %%
safi_df
# Out:
#                                            key_ID   village  \
# instanceID
# uuid:099de9c9-3e5e-427b-8452-26250e840d6e       1       God
# uuid:ae20a58d-56f4-43d7-bafa-e7963d850844       7       God
# uuid:d6cee930-7be1-4fd9-88c0-82a08f90fb5a       8  Chirodzo
# uuid:846103d2-b1db-4055-b502-9cd510bb7b37       9  Chirodzo
# uuid:8f4e49bc-da81-4356-ae34-e0d794a23721      10  Chirodzo
# uuid:e6ee6269-b467-4e37-91fc-5e9eaf934557      12       God
# uuid:6c00c145-ee3b-409c-8c02-2c8d743b6918      13       God
# uuid:a837e545-ff86-4a1c-a1a5-6186804b985f      15       God
# uuid:661457d3-7e61-45e8-a238-7415e7548f82      24     Ruaca
# uuid:45ed84c4-114e-4df0-9f5d-c800806c2bee      25     Ruaca
# uuid:1c54ee24-22c4-4ee9-b1ad-42d483c08e2e      26     Ruaca
# uuid:adcd7463-8943-4c67-b25f-f72311409476      29     Ruaca
# uuid:25597af3-cd79-449c-a48a-fb9aea6c48bf      32     Ruaca
# uuid:0fbd2df1-2640-4550-9fbd-7317feaa4758      33     Ruaca
# ...

# %%
grouped_data = safi_df.groupby('respondent_wall_type')
grouped_data.describe()
# Out:
#                      key_ID                                              \
#                       count        mean        std    min    25%    50%
# respondent_wall_type
#  muddaub                1.0    1.000000        NaN    1.0    1.0    1.0
# burntbricks            50.0   95.120000  63.021098    8.0   47.5   74.5
# cement                  1.0  193.000000        NaN  193.0  193.0  193.0
# muddaub                23.0   97.565217  63.809251    7.0   44.0   72.0
# sunbricks              13.0  108.615385  56.290228   15.0   85.0  105.0
#
#                                    liv_count            ...  rooms       \
#                         75%    max     count      mean  ...    75%  max
# respondent_wall_type                                    ...
#  muddaub                1.0    1.0       1.0  3.000000  ...    1.0  1.0
# burntbricks           150.0  202.0      50.0  2.740000  ...    3.0  5.0
# cement                193.0  193.0       1.0  3.000000  ...    3.0  3.0
# ...

# %%
grouped_data['liv_count'].describe()
# Out:
#                       count      mean       std  min  25%  50%  75%  max
# respondent_wall_type
#  muddaub                1.0  3.000000       NaN  3.0  3.0  3.0  3.0  3.0
# burntbricks            50.0  2.740000  0.943506  1.0  2.0  3.0  3.0  5.0
# cement                  1.0  3.000000       NaN  3.0  3.0  3.0  3.0  3.0
# muddaub                23.0  2.217391  1.241572  1.0  1.0  2.0  3.0  5.0
# sunbricks              13.0  2.769231  1.012739  1.0  2.0  3.0  3.0  5.0

# %%
grouped_data_village = safi_df.groupby(['respondent_wall_type','village'])
grouped_data_village['liv_count'].describe()
# Out:
#                                count      mean       std  min   25%  50%  \
# respondent_wall_type village
#  muddaub             God         1.0  3.000000       NaN  3.0  3.00  3.0
# burntbricks          Chirodzo   18.0  2.666667  0.970143  1.0  2.00  3.0
#                      God        10.0  2.700000  0.823273  1.0  2.25  3.0
#                      Ruaca      22.0  2.818182  1.006473  1.0  2.00  3.0
# cement               Ruaca       1.0  3.000000       NaN  3.0  3.00  3.0
# muddaub              Chirodzo    7.0  2.000000  1.154701  1.0  1.00  2.0
#                      God         6.0  2.166667  1.169045  1.0  1.25  2.0
#                      Ruaca      10.0  2.400000  1.429841  1.0  1.00  2.5
# sunbricks            Chirodzo    1.0  3.000000       NaN  3.0  3.00  3.0
#                      God         6.0  2.333333  0.816497  1.0  2.00  2.5
#                      Ruaca       6.0  3.166667  1.169045  2.0  2.25  3.0
#
#                                 75%  max
# ...

# %%
# %load code/groupby

# %% [markdown]
# 1. Read in the SAFI_clean.csv dataset.
# 2. Get a list of the different `rooms` values.
# 3. Groupby `rooms` and describe the results.
# 4. Remove all rows with NaN values.
# 5. repeat steps 2 & 3 and compare the results.

# %%
safi_clean = pd.read_csv('data/SAFI_clean.csv')

# %%
rooms_list =pd.unique(safi_clean.rooms)
rooms_list
# Out:
# array([1, 3, 5, 2, 4, 8])

# %%
safi_by_rooms = safi_clean.groupby('rooms')
safi_by_rooms

# %%
safi_by_rooms.describe()
# Out:
#       key_ID                                                            \
#        count        mean        std    min    25%    50%    75%    max
# rooms
# 1       73.0   78.958904  61.534416    1.0   33.0   61.0  125.0  198.0
# 2       33.0  100.515152  66.276938   15.0   46.0   76.0  174.0  201.0
# 3       17.0   70.352941  55.865845    8.0   25.0   59.0  110.0  193.0
# 4        5.0  135.400000  71.716804   23.0  117.0  144.0  191.0  202.0
# 5        2.0   58.000000  67.882251   10.0   34.0   58.0   82.0  106.0
# 8        1.0  127.000000        NaN  127.0  127.0  127.0  127.0  127.0
#
#       liv_count            ...  no_membrs       years_liv             \
#           count      mean  ...        75%   max     count       mean
# rooms                      ...
# 1          73.0  2.068493  ...       7.00  15.0      73.0  21.095890
# 2          33.0  2.848485  ...      10.00  19.0      33.0  26.181818
# 3          17.0  2.823529  ...      11.00  12.0      17.0  28.411765
# ...

# %%
safi_by_rooms_nonan = safi_clean.dropna().groupby('rooms')
safi_by_rooms_nonan.describe()
# Out:
#       key_ID                                                             \
#        count        mean        std    min     25%    50%    75%    max
# rooms
# 1       44.0   98.295455  60.959605    1.0   44.50   84.0  160.5  195.0
# 2       25.0  104.840000  63.948339   15.0   56.00   89.0  174.0  199.0
# 3       14.0   71.928571  58.515566    8.0   27.25   61.5   99.5  193.0
# 4        3.0  179.000000  30.805844  144.0  167.50  191.0  196.5  202.0
# 5        2.0   58.000000  67.882251   10.0   34.00   58.0   82.0  106.0
#
#       liv_count            ...  no_membrs       years_liv             \
#           count      mean  ...        75%   max     count       mean
# rooms                      ...
# 1          44.0  2.318182  ...       8.25  15.0      44.0  23.000000
# 2          25.0  3.080000  ...      11.00  19.0      25.0  27.680000
# 3          14.0  2.785714  ...      11.00  12.0      14.0  27.000000
# 4           3.0  2.666667  ...      11.00  12.0       3.0   7.333333
# ...
