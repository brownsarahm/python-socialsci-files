# %% [markdown]
# # Joining Pandas DataFrames

# %%
import pandas as pd

# %%
safi_god = pd.read_csv('data/SAFI_God.csv')
safi_ruaca = pd.read_csv('data/SAFI_Ruaca.csv')

# %%
safi_god.head()
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0       1     God  2016-11-17T00:00:00Z          3          4
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
# 4       5     God  2016-11-17T00:00:00Z          7         40
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0              muddaub      1        NaN              NaN          1
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
# 4          burntbricks      1        NaN              NaN          4
#
#                                          items_owned  no_meals  \
# 0               bicycle;television;solar_panel;table         2
# ...

# %%
safi_ruaca.head()
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0      23   Ruaca  2016-11-21T00:00:00Z         10         20
# 1      24   Ruaca  2016-11-21T00:00:00Z          6          4
# 2      25   Ruaca  2016-11-21T00:00:00Z         11          6
# 3      26   Ruaca  2016-11-21T00:00:00Z          3         20
# 4      27   Ruaca  2016-11-21T00:00:00Z          7         36
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0          burntbricks      4        NaN              NaN          3
# 1          burntbricks      2         no            never          3
# 2          burntbricks      3         no            never          2
# 3          burntbricks      2         no            never          2
# 4          burntbricks      2        NaN              NaN          3
#
#                                          items_owned  no_meals  \
# 0  cow_cart;bicycle;television;radio;cow_plough;s...         3
# ...

# %%
df_safi = pd.concat([safi_god, safi_ruaca])
df_safi
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 0        1     God  2016-11-17T00:00:00Z          3          4
# 1        1     God  2016-11-17T00:00:00Z          7          9
# 2        3     God  2016-11-17T00:00:00Z         10         15
# 3        4     God  2016-11-17T00:00:00Z          7          6
# 4        5     God  2016-11-17T00:00:00Z          7         40
# ..     ...     ...                   ...        ...        ...
# 44     189   Ruaca  2017-06-03T00:00:00Z         15         16
# 45     191   Ruaca  2017-06-03T00:00:00Z         10          5
# 46     126   Ruaca  2017-05-18T00:00:00Z          3          7
# 47     193   Ruaca  2017-06-04T00:00:00Z          7         10
# 48     194   Ruaca  2017-06-04T00:00:00Z          4          5
#
#    respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0               muddaub      1        NaN              NaN          1
# ...

# %%
safi_god04 = pd.read_csv('data/SAFI_God.csv', usecols=range(0,4))

safi_ruaca25 = pd.read_csv('data/SAFI_Ruaca.csv', usecols=range(2,5))

# %%
safi_god04.columns
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_membrs'], dtype='object')

# %%
safi_ruaca25.columns
# Out:
# Index(['interview_date', 'no_membrs', 'years_liv'], dtype='object')

# %%
pd.concat([safi_god04,safi_ruaca25])
# Out:
#     key_ID village        interview_date  no_membrs  years_liv
# 0      1.0     God  2016-11-17T00:00:00Z          3        NaN
# 1      1.0     God  2016-11-17T00:00:00Z          7        NaN
# 2      3.0     God  2016-11-17T00:00:00Z         10        NaN
# 3      4.0     God  2016-11-17T00:00:00Z          7        NaN
# 4      5.0     God  2016-11-17T00:00:00Z          7        NaN
# ..     ...     ...                   ...        ...        ...
# 44     NaN     NaN  2017-06-03T00:00:00Z         15       16.0
# 45     NaN     NaN  2017-06-03T00:00:00Z         10        5.0
# 46     NaN     NaN  2017-05-18T00:00:00Z          3        7.0
# 47     NaN     NaN  2017-06-04T00:00:00Z          7       10.0
# 48     NaN     NaN  2017-06-04T00:00:00Z          4        5.0
#
# [92 rows x 5 columns]

# %%
df_safi
# Out:
#     key_ID village        interview_date  no_membrs  years_liv  \
# 0        1     God  2016-11-17T00:00:00Z          3          4
# 1        1     God  2016-11-17T00:00:00Z          7          9
# 2        3     God  2016-11-17T00:00:00Z         10         15
# 3        4     God  2016-11-17T00:00:00Z          7          6
# 4        5     God  2016-11-17T00:00:00Z          7         40
# ..     ...     ...                   ...        ...        ...
# 44     189   Ruaca  2017-06-03T00:00:00Z         15         16
# 45     191   Ruaca  2017-06-03T00:00:00Z         10          5
# 46     126   Ruaca  2017-05-18T00:00:00Z          3          7
# 47     193   Ruaca  2017-06-04T00:00:00Z          7         10
# 48     194   Ruaca  2017-06-04T00:00:00Z          4          5
#
#    respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0               muddaub      1        NaN              NaN          1
# ...

# %%
df_safi.to_csv('data/SAFI_God_Ruaca.csv')

# %%
safi_partrial = pd.concat([safi_god04,safi_ruaca25])
safi_partrial.dropna()
# Out:
# Empty DataFrame
# Columns: [key_ID, village, interview_date, no_membrs, years_liv]
# Index: []

# %%
safi_num = pd.read_csv('data/SAFI_numCols.csv')
safi_char = pd.read_csv('data/SAFI_charCols.csv')

# %%
safi_num.head(2)
# Out:
#                                   instanceID  no_membrs  years_liv  rooms
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1

# %%
safi_char.head(2)
# Out:
#                                   instanceID village respondent_wall_type  \
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef     God              muddaub
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e     God              muddaub
#
#                                          items_owned
# 0               bicycle;television;solar_panel;table
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...

# %%
safi_all_cols = pd.concat([safi_num, safi_char],axis=1)
safi_all_cols.head()
# Out:
#                                   instanceID  no_membrs  years_liv  rooms  \
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
# 2  uuid:193d7daf-9582-409b-bf09-027dd36f9007         10         15      1
# 3  uuid:148d1105-778a-4755-aa71-281eadd4a973          7          6      1
# 4  uuid:2c867811-9696-4966-9866-f35c3e97d02d          7         40      1
#
#                                   instanceID village respondent_wall_type  \
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef     God              muddaub
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e     God              muddaub
# 2  uuid:193d7daf-9582-409b-bf09-027dd36f9007     God          burntbricks
# 3  uuid:148d1105-778a-4755-aa71-281eadd4a973     God          burntbricks
# 4  uuid:2c867811-9696-4966-9866-f35c3e97d02d     God          burntbricks
#
#                                          items_owned
# ...

# %%
safi_join = pd.merge(safi_num,safi_char)
safi_join.head(2)
# Out:
#                                   instanceID  no_membrs  years_liv  rooms  \
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef          3          4      1
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e          7          9      1
#
#   village respondent_wall_type  \
# 0     God              muddaub
# 1     God              muddaub
#
#                                          items_owned
# 0               bicycle;television;solar_panel;table
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...
