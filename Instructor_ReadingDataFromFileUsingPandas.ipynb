# %% [markdown]
# # Introduction to pandas
# ## how to read data into python

# %%
# import the pandas library
import pandas as pd

# %%
# read the data into python
safi = pd.read_csv('data/SAFI_clean.csv')

# %%
safi
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %%
print(safi)
# Out:
#      key_ID   village        interview_date  no_membrs  years_liv  \
# 0         1       God  2016-11-17T00:00:00Z          3          4
# 1         1       God  2016-11-17T00:00:00Z          7          9
# 2         3       God  2016-11-17T00:00:00Z         10         15
# 3         4       God  2016-11-17T00:00:00Z          7          6
# 4         5       God  2016-11-17T00:00:00Z          7         40
# 5         6       God  2016-11-17T00:00:00Z          3          3
# 6         7       God  2016-11-17T00:00:00Z          6         38
# 7         8  Chirodzo  2016-11-16T00:00:00Z         12         70
# 8         9  Chirodzo  2016-11-16T00:00:00Z          8          6
# 9        10  Chirodzo  2016-12-16T00:00:00Z         12         23
# 10       11       God  2016-11-21T00:00:00Z          6         20
# 11       12       God  2016-11-21T00:00:00Z          7         20
# 12       13       God  2016-11-21T00:00:00Z          6          8
# ...

# %% [markdown]
# # %load code/csv-sep
# What happens if you specify the tab character as column separator with `sep='\t'`?

# %% [markdown]
# ### Solution
# If we declare a seperator that is not present in our data, python reads all data as one column!, see below

# %%
pd.read_csv('data/SAFI_clean.csv', sep='\t')
# Out:
#     key_ID,village,interview_date,no_membrs,years_liv,respondent_wall_type,rooms,memb_assoc,affect_conflicts,liv_count,items_owned,no_meals,months_lack_food,instanceID
# 0    1,God,2016-11-17T00:00:00Z,3,4,muddaub,1,NULL,...
# 1    1,God,2016-11-17T00:00:00Z,7,9, muddaub,1,yes,...
# 2    3,God,2016-11-17T00:00:00Z,10,15, burntbricks,...
# 3    4,God,2016-11-17T00:00:00Z,7,6, burntbricks,1,...
# 4    5,God,2016-11-17T00:00:00Z,7,40,burntbricks,1,...
# 5    6,God,2016-11-17T00:00:00Z,3,3,muddaub,1,NULL,...
# 6    7,God,2016-11-17T00:00:00Z,6,38,muddaub,1,no,n...
# 7    8,Chirodzo,2016-11-16T00:00:00Z,12,70,burntbri...
# 8    9,Chirodzo,2016-11-16T00:00:00Z,8,6,burntbrick...
# 9    10,Chirodzo,2016-12-16T00:00:00Z,12,23,burntbr...
# 10   11,God,2016-11-21T00:00:00Z,6,20,sunbricks,1,N...
# 11   12,God,2016-11-21T00:00:00Z,7,20,burntbricks,3...
# 12   13,God,2016-11-21T00:00:00Z,6,8,burntbricks,1,...
# 13   14,God,2016-11-21T00:00:00Z,10,20,burntbricks,...
# ...

# %%
# check what datatype our python object (or variable) safi has
type(safi)
# Out:
# pandas.core.frame.DataFrame

# %%
# check what datatypes the individual columns have in our DataFrame safi
safi.dtypes
# Out:
# key_ID                   int64
# village                 object
# interview_date          object
# no_membrs                int64
# years_liv                int64
# respondent_wall_type    object
# rooms                    int64
# memb_assoc              object
# affect_conflicts        object
# liv_count                int64
# items_owned             object
# no_meals                 int64
# months_lack_food        object
# instanceID              object
# dtype: object

# %%
# only print out the first few rows of a DataFrame
safi.head()
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0       1     God  2016-11-17T00:00:00Z          3          4
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
# 3       4     God  2016-11-17T00:00:00Z          7          6
# 4       5     God  2016-11-17T00:00:00Z          7         40
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0              muddaub      1        NaN              NaN          1
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
# 3          burntbricks      1        NaN              NaN          2
# 4          burntbricks      1        NaN              NaN          4
#
#                                          items_owned  no_meals  \
# 0               bicycle;television;solar_panel;table         2
# ...

# %% [markdown]
# # %load code/headtail
# 1. As well as the `head()` method there is a `tail()` method. What do you think it does? Try it.
#
# 2. Both methods accept a single numeric parameter. What do you think it does? Try it.

# %% [markdown]
# ### Solution
# 1. tail() prints out the last few rows
# 2. by default head() and tail() print the first/last 5 rows, we can use the parameter n to give a different number, e.g. n = 3

# %%
safi.head(n = 3)
# Out:
#    key_ID village        interview_date  no_membrs  years_liv  \
# 0       1     God  2016-11-17T00:00:00Z          3          4
# 1       1     God  2016-11-17T00:00:00Z          7          9
# 2       3     God  2016-11-17T00:00:00Z         10         15
#
#   respondent_wall_type  rooms memb_assoc affect_conflicts  liv_count  \
# 0              muddaub      1        NaN              NaN          1
# 1              muddaub      1        yes             once          3
# 2          burntbricks      1        NaN              NaN          1
#
#                                          items_owned  no_meals  \
# 0               bicycle;television;solar_panel;table         2
# 1  cow_cart;bicycle;radio;cow_plough;solar_panel;...         2
# 2                                        solar_torch         2
#
#           months_lack_food                                 instanceID
# 0                      Jan  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef
# ...

# %%
# return the shape, i.e. number of rows and number of columns of a DataFram
safi.shape
# Out:
# (131, 14)

# %%
# return the names of the columns of a DataFrame
safi.columns
# Out:
# Index(['key_ID', 'village', 'interview_date', 'no_membrs', 'years_liv',
#        'respondent_wall_type', 'rooms', 'memb_assoc', 'affect_conflicts',
#        'liv_count', 'items_owned', 'no_meals', 'months_lack_food',
#        'instanceID'],
#       dtype='object')
